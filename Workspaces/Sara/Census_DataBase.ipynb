# %%
# SQLAlchemy
from sqlalchemy import create_engine
import pandas as pd

# Imports the methods needed to abstract classes into tables
from sqlalchemy.ext.declarative import declarative_base

# Allow us to declare column types
from sqlalchemy import Column, Integer, String, Float, insert
from sqlalchemy.orm import sessionmaker

# %%
df = pd.read_csv(r'ACSDP5Y2018.DP02_data_with_overlays_2020-07-19T201042.csv')
df
# Out:
#                    GEO_ID                                         NAME  \
# 0                      id                         Geographic Area Name
# 1    1400000US41001950100      Census Tract 9501, Baker County, Oregon
# 2    1400000US41001950200      Census Tract 9502, Baker County, Oregon
# 3    1400000US41001950300      Census Tract 9503, Baker County, Oregon
# 4    1400000US41001950400      Census Tract 9504, Baker County, Oregon
# ..                    ...                                          ...
# 830  1400000US41071030702  Census Tract 307.02, Yamhill County, Oregon
# 831  1400000US41071030801  Census Tract 308.01, Yamhill County, Oregon
# 832  1400000US41071030802  Census Tract 308.02, Yamhill County, Oregon
# 833  1400000US41071030900     Census Tract 309, Yamhill County, Oregon
# 834  1400000US41071031000     Census Tract 310, Yamhill County, Oregon
#
#                                          DP02_0001E  \
# 0    Estimate!!HOUSEHOLDS BY TYPE!!Total households
# ...

# %%
engine = create_engine("sqlite:///Internet_Data.db", echo=True)
conn = engine.connect()
# Out:
# 2020-07-22 18:20:26,201 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-07-22 18:20:26,202 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-22 18:20:26,203 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-07-22 18:20:26,204 INFO sqlalchemy.engine.base.Engine ()

# %%
# Sets an object to utilize the default declarative base in SQL Alchemy
Base = declarative_base()



# Creates Classes which will serve as the anchor points for our Tables
class Census_Data(Base):
    __tablename__ = 'Census_Data'
    GEO_ID = Column(String(255), primary_key=True)
    StateTractCode = Column(Integer)
    Name = Column(String(255))
    DP02_0001E = Column(Float)
    DP02_0001PE = Column(Float)
    DP02_0002E = Column(Float)
    DP02_0002PE = Column(Float)
    DP02_0003E = Column(Float)
    DP02_0003PE = Column(Float)
    DP02_0004E = Column(Float)
    DP02_0004PE = Column(Float)
    DP02_0005E = Column(Float)
    DP02_0005PE = Column(Float)
    DP02_0006E = Column(Float)
    DP02_0006PE = Column(Float)
    DP02_0007E = Column(Float)
    DP02_0007PE = Column(Float)
    DP02_0008E = Column(Float)
    DP02_0008PE = Column(Float)
    DP02_0009E = Column(Float)
    DP02_0009PE = Column(Float)
    DP02_0010E = Column(Float)
    DP02_0010PE = Column(Float)
    DP02_0011E = Column(Float)
    DP02_0011PE = Column(Float)
    DP02_0012E = Column(Float)
    DP02_0012PE = Column(Float)
    DP02_0013E = Column(Float)
    DP02_0013PE = Column(Float)
    DP02_0014E = Column(Float)
    DP02_0014PE = Column(Float)
    DP02_0015E = Column(Float)
    DP02_0015PE = Column(Float)
    DP02_0016E = Column(Float)
    DP02_0016PE = Column(Float)
    DP02_0017E = Column(Float)
    DP02_0017PE = Column(Float)
    DP02_0018E = Column(Float)
    DP02_0018PE = Column(Float)
    DP02_0019E = Column(Float)
    DP02_0019PE = Column(Float)
    DP02_0020E = Column(Float)
    DP02_0020PE = Column(Float)
    DP02_0021E = Column(Float)
    DP02_0021PE = Column(Float)
    DP02_0022E = Column(Float)
    DP02_0022PE = Column(Float)
    DP02_0023E = Column(Float)
    DP02_0023PE = Column(Float)
    DP02_0024E = Column(Float)
    DP02_0024PE = Column(Float)
    DP02_0025E = Column(Float)
    DP02_0025PE = Column(Float)
    DP02_0026E = Column(Float)
    DP02_0026PE = Column(Float)
    DP02_0027E = Column(Float)
    DP02_0027PE = Column(Float)
    DP02_0028E = Column(Float)
    DP02_0028PE = Column(Float)
    DP02_0029E = Column(Float)
    DP02_0029PE = Column(Float)
    DP02_0030E = Column(Float)
    DP02_0030PE = Column(Float)
    DP02_0031E = Column(Float)
    DP02_0031PE = Column(Float)
    DP02_0032E = Column(Float)
    DP02_0032PE = Column(Float)
    DP02_0033E = Column(Float)
    DP02_0033PE = Column(Float)
    DP02_0034E = Column(Float)
    DP02_0034PE = Column(Float)
    DP02_0035E = Column(Float)
    DP02_0035PE = Column(Float)
    DP02_0036E = Column(Float)
    DP02_0036PE = Column(Float)
    DP02_0037E = Column(Float)
    DP02_0037PE = Column(Float)
    DP02_0038E = Column(Float)
    DP02_0038PE = Column(Float)
    DP02_0039E = Column(Float)
    DP02_0039PE = Column(Float)
    DP02_0040E = Column(Float)
    DP02_0040PE = Column(Float)
    DP02_0041E = Column(Float)
    DP02_0041PE = Column(Float)
    DP02_0042E = Column(Float)
    DP02_0042PE = Column(Float)
    DP02_0043E = Column(Float)
    DP02_0043PE = Column(Float)
    DP02_0044E = Column(Float)
    DP02_0044PE = Column(Float)
    DP02_0045E = Column(Float)
    DP02_0045PE = Column(Float)
    DP02_0046E = Column(Float)
    DP02_0046PE = Column(Float)
    DP02_0047E = Column(Float)
    DP02_0047PE = Column(Float)
    DP02_0048E = Column(Float)
    DP02_0048PE = Column(Float)
    DP02_0049E = Column(Float)
    DP02_0049PE = Column(Float)
    DP02_0050E = Column(Float)
    DP02_0050PE = Column(Float)
    DP02_0051E = Column(Float)
    DP02_0051PE = Column(Float)
    DP02_0052E = Column(Float)
    DP02_0052PE = Column(Float)
    DP02_0053E = Column(Float)
    DP02_0053PE = Column(Float)
    DP02_0054E = Column(Float)
    DP02_0054PE = Column(Float)
    DP02_0055E = Column(Float)
    DP02_0055PE = Column(Float)
    DP02_0056E = Column(Float)
    DP02_0056PE = Column(Float)
    DP02_0057E = Column(Float)
    DP02_0057PE = Column(Float)
    DP02_0058E = Column(Float)
    DP02_0058PE = Column(Float)
    DP02_0059E = Column(Float)
    DP02_0059PE = Column(Float)
    DP02_0060E = Column(Float)
    DP02_0060PE = Column(Float)
    DP02_0061E = Column(Float)
    DP02_0061PE = Column(Float)
    DP02_0062E = Column(Float)
    DP02_0062PE = Column(Float)
    DP02_0063E = Column(Float)
    DP02_0063PE = Column(Float)
    DP02_0064E = Column(Float)
    DP02_0064PE = Column(Float)
    DP02_0065E = Column(Float)
    DP02_0065PE = Column(Float)
    DP02_0066E = Column(Float)
    DP02_0066PE = Column(Float)
    DP02_0067E = Column(Float)
    DP02_0067PE = Column(Float)
    DP02_0068E = Column(Float)
    DP02_0068PE = Column(Float)
    DP02_0069E = Column(Float)
    DP02_0069PE = Column(Float)
    DP02_0070E = Column(Float)
    DP02_0070PE = Column(Float)
    DP02_0071E = Column(Float)
    DP02_0071PE = Column(Float)
    DP02_0072E = Column(Float)
    DP02_0072PE = Column(Float)
    DP02_0073E = Column(Float)
    DP02_0073PE = Column(Float)
    DP02_0074E = Column(Float)
    DP02_0074PE = Column(Float)
    DP02_0075E = Column(Float)
    DP02_0075PE = Column(Float)
    DP02_0076E = Column(Float)
    DP02_0076PE = Column(Float)
    DP02_0077E = Column(Float)
    DP02_0077PE = Column(Float)
    DP02_0078E = Column(Float)
    DP02_0078PE = Column(Float)
    DP02_0079E = Column(Float)
    DP02_0079PE = Column(Float)
    DP02_0080E = Column(Float)
    DP02_0080PE = Column(Float)
    DP02_0081E = Column(Float)
    DP02_0081PE = Column(Float)
    DP02_0082E = Column(Float)
    DP02_0082PE = Column(Float)
    DP02_0083E = Column(Float)
    DP02_0083PE = Column(Float)
    DP02_0084E = Column(Float)
    DP02_0084PE = Column(Float)
    DP02_0085E = Column(Float)
    DP02_0085PE = Column(Float)
    DP02_0086E = Column(Float)
    DP02_0086PE = Column(Float)
    DP02_0087E = Column(Float)
    DP02_0087PE = Column(Float)
    DP02_0088E = Column(Float)
    DP02_0088PE = Column(Float)
    DP02_0089E = Column(Float)
    DP02_0089PE = Column(Float)
    DP02_0090E = Column(Float)
    DP02_0090PE = Column(Float)
    DP02_0091E = Column(Float)
    DP02_0091PE = Column(Float)
    DP02_0092E = Column(Float)
    DP02_0092PE = Column(Float)
    DP02_0093E = Column(Float)
    DP02_0093PE = Column(Float)
    DP02_0094E = Column(Float)
    DP02_0094PE = Column(Float)
    DP02_0095E = Column(Float)
    DP02_0095PE = Column(Float)
    DP02_0096E = Column(Float)
    DP02_0096PE = Column(Float)
    DP02_0097E = Column(Float)
    DP02_0097PE = Column(Float)
    DP02_0098E = Column(Float)
    DP02_0098PE = Column(Float)
    DP02_0099E = Column(Float)
    DP02_0099PE = Column(Float)
    DP02_0100E = Column(Float)
    DP02_0100PE = Column(Float)
    DP02_0101E = Column(Float)
    DP02_0101PE = Column(Float)
    DP02_0102E =  Column(Float)
    DP02_0102PE = Column(Float)
    DP02_0103E = Column(Float)
    DP02_0103PE = Column(Float)
    DP02_0104PE = Column(Float)
    DP02_0105E  = Column(Float)
    DP02_0105PE = Column(Float)
    DP02_0106E = Column(Float)
    DP02_0106PE = Column(Float)
    DP02_0107E = Column(Float)
    DP02_0107PE = Column(Float)
    DP02_0108E = Column(Float)
    DP02_0108PE = Column(Float)
    DP02_0109E = Column(Float)
    DP02_0109PE = Column(Float)
    DP02_0110E = Column(Float)
    DP02_0110PE = Column(Float)
    DP02_0111E = Column(Float)
    DP02_0111PE = Column(Float)
    DP02_0112E = Column(Float)
    DP02_0112PE = Column(Float)
    DP02_0113E = Column(Float)
    DP02_0113PE = Column(Float)
    DP02_0114E = Column(Float)
    DP02_0114PE = Column(Float)
    DP02_0115E = Column(Float)
    DP02_0115PE = Column(Float)
    DP02_0116E = Column(Float)
    DP02_0116PE = Column(Float)
    DP02_0117E = Column(Float)
    DP02_0117PE = Column(Float)
    DP02_0118E = Column(Float)
    DP02_0118PE = Column(Float)
    DP02_0119E = Column(Float)
    DP02_0119PE = Column(Float)
    DP02_0120E = Column(Float)
    DP02_0120PE = Column(Float)
    DP02_0121E = Column(Float)
    DP02_0121PE = Column(Float)
    DP02_0122E = Column(Float)
    DP02_0122PE = Column(Float)
    DP02_0123E = Column(Float)
    DP02_0123PE = Column(Float)
    DP02_0124E = Column(Float)
    DP02_0124PE = Column(Float)
    DP02_0125E = Column(Float)
    DP02_0125PE = Column(Float)
    DP02_0126E = Column(Float)
    DP02_0126PE = Column(Float) 
    DP02_0127E = Column(Float)
    DP02_0127PE = Column(Float)
    DP02_0128E = Column(Float)
    DP02_0128PE = Column(Float)
    DP02_0129E = Column(Float)
    DP02_0129PE = Column(Float)
    DP02_0130E = Column(Float)
    DP02_0130PE = Column(Float)
    DP02_0131PE = Column(Float)
    DP02_0132E = Column(Float)
    DP02_0132PE = Column(Float)
    DP02_0133E = Column(Float)
    DP02_0133PE = Column(Float)
    DP02_0134E = Column(Float)
    DP02_0134PE = Column(Float)
    DP02_0135E = Column(Float)
    DP02_0135PE = Column(Float)
    DP02_0136E = Column(Float)
    DP02_0136PE = Column(Float)
    DP02_0137E = Column(Float)
    DP02_0137PE = Column(Float)
    DP02_0138E = Column(Float)
    DP02_0138PE = Column(Float)
    DP02_0139E = Column(Float)
    DP02_0139PE = Column(Float)
    DP02_0140E = Column(Float)
    DP02_0140PE = Column(Float)
    DP02_0141E = Column(Float)
    DP02_0141PE = Column(Float)
    DP02_0142E = Column(Float)
    DP02_0142PE = Column(Float)
    DP02_0143E = Column(Float)
    DP02_0143PE = Column(Float)
    DP02_0144E = Column(Float)
    DP02_0144PE = Column(Float)
    DP02_0145E = Column(Float)
    DP02_0145PE = Column(Float)
    DP02_0146E = Column(Float)
    DP02_0146PE = Column(Float)
    DP02_0147E = Column(Float)
    DP02_0147PE = Column(Float)
    DP02_0148E = Column(Float)
    DP02_0148PE = Column(Float)
    DP02_0149E = Column(Float)
    DP02_0149PE = Column(Float)
    DP02_0150E = Column(Float)
    DP02_0150PE = Column(Float)
    DP02_0151E = Column(Float)
    DP02_0151PE = Column(Float)
    DP02_0152E = Column(Float)
    DP02_0152PE = Column(Float)


#class Meta_Data(Base):
#    __tablename__ = 'Meta_Data'
#    Code = Column(String(255), primary_key=True)
#    TableCode = Column(String(255))
#    ColumnCode = Column(String(255))
#    ColumnNumber = Column(String(255))
#    ColumnNumeric = Column(String(255))
#    ColumnLetter = Column(String(255))
#    ColumnTitle = Column(String(255))

# %%
# Create a Specific Instance of the Dog and Cat classes
# I am not really sure how to do this. Maybe Steven can help?

'''insert_query = Census_Data.insert()

with open('ACSDP5Y2018-Copy2.DP02_data_with_overlays_2020-07-19T201042', 'r', encoding="utf-8") as csvfile:
    csv_reader = csv.reader(csvfile, delimiter=',')
    engine.execute(
        insert_query, 
            for row in csv_reader {['DP02_0001E';[0]:'DP02_0152PE';[830]]}
    ) '''
# This didn't work. I am trying something else to read in the csv data
# Out:
#   File "<ipython-input-38-7df5531a67a7>", line 10
#     for row in csv_reader {['DP02_0001E';[0]:'DP02_0152PE';[830]]}
#       ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv('ACSDP5Y2018-Copy2.DP02_data_with_overlays_2020-07-19T201042.csv', 'r', encoding="utf-8", error_bad_lines = False)
#df_New = df[['GEO_ID', 'StateTractCode']]
df.to_sql('Census_Data', conn, if_exists='replace', index=False)
#Create table first? 
#df_New.iloc[144:148]
# Out:
# 2020-07-22 18:20:59,037 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("Census_Data")
# 2020-07-22 18:20:59,037 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-22 18:20:59,038 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("Census_Data")
# 2020-07-22 18:20:59,039 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-22 18:20:59,040 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE "Census_Data" (
# 	"GEO_ID,StateT" TEXT,
# ...

# %%
# Create Database Connection
# ----------------------------------
# Creates a connection to our DB
engine = create_engine("sqlite:///Internet_Data.db", echo=True)
conn = engine.connect()
# Out:
# 2020-07-22 18:25:55,670 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-07-22 18:25:55,671 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-22 18:25:55,672 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-07-22 18:25:55,673 INFO sqlalchemy.engine.base.Engine ()

# %%
# Create a "Metadata" Layer That Abstracts our SQL Database
# ----------------------------------
# Create (if not already in existence) the tables associated with our classes.
Base.metadata.create_all(engine)

# Use this to clear out the db
# ----------------------------------
# Base.metadata.drop_all(engine)

# %%
# Create a Session Object to Connect to DB
# ----------------------------------
# Session is a temporary binding to our DB
from sqlalchemy.orm import Session
session = Session(bind=engine)

# %%
# Query the Tables
# ----------------------------------
# Perform a simple query of the database
dog_list = session.query(Dog)
for doggy in dog_list:
    print(doggy.name)

# %%
# Create an engine that can talk to the database
#engine = create_engine(f"sqlite:///{database_path}")

# %%
# Query All Records in the the Database
#data = engine.execute("SELECT * FROM Census_Data")

#for record in data:
#    print(record)
