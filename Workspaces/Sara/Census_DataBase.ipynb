# %%
# SQLAlchemy
from sqlalchemy import create_engine
import pandas as pd

# Imports the methods needed to abstract classes into tables
from sqlalchemy.ext.declarative import declarative_base

# Allow us to declare column types
from sqlalchemy import Column, Integer, String, Float, insert
from sqlalchemy.orm import sessionmaker

# %%
df = pd.read_csv(r'fcc_data.csv')
df
# Out:
#      Unnamed: 0  logrecno  provider_id       frn       providername  \
# 0             0      4268        48582  17678236  Webformix Company
# 1             1      4269        48582  17678236  Webformix Company
# 2             2      4270        48582  17678236  Webformix Company
# 3             3      4271        48582  17678236  Webformix Company
# 4             4      4272        48582  17678236  Webformix Company
# ..          ...       ...          ...       ...                ...
# 995         995      5263        48582  17678236  Webformix Company
# 996         996      5264        48582  17678236  Webformix Company
# 997         997      5265        48582  17678236  Webformix Company
# 998         998      5266        48582  17678236  Webformix Company
# 999         999      5267        48582  17678236  Webformix Company
#
#        dbaname holdingcompanyname  hoconum          hocofinal stateabbr  \
# 0    Webformix  Webformix Company   290118  Webformix Company        OR
# ...

# %%
engine = create_engine("sqlite:///Internet_Data.db", echo=False)
conn = engine.connect()

# %%
# Sets an object to utilize the default declarative base in SQL Alchemy
Base = declarative_base()

# Creates Classes which will serve as the anchor points for our Tables
class Census_Data(Base):
    __tablename__ = 'Census_Data'
    GEO_ID = Column(String(255), primary_key=True)
    StateTractCode = Column(Integer)
    Name = Column(String(255))
    households = Column(Float)
    Percent_households = Column(Float)
    households_Family_households = Column(Float)
    Percent_households_Family_households_families = Column(Float)
    TYPE_Total_households_Family_households_With_own_children_under_18 = Column(Float)
    PE_HH_TYPE_Total_households_Family_households_With_own_children_under_18 = Column(Float)
    E_HH_TYPE_Total_households_Married_couple_family = Column(Float)
    PE_HH_TYPE_Total_households_Married_couple_family = Column(Float)
    E_HH_TYPE_Total_households_Married_couple_family_With_own_children_under_18_years = Column(Float)
    PE_HH_TYPE_Total_households_Married_couple_family_With_own_children_under_18_years = Column(Float)
    E_HH_TYPE_Total_Male_householder,_no_wife_present = Column(Float)
    PE_HH_TYPE_Total_Male_householder,_no_wife_present = Column(Float)
    E_HH_TYPE_Total_Male_householder,_no_wife_present_With_own_under_18_years = Column(Float)
    PE_HH_TYPE_Total_Male_householder,_no_wife_present_With_own_under_18_years = Column(Float)
    E_HH_TYPE_Total_Female_householder,_no_husband_present = Column(Float)
    PE_HH_TYPE_Total_Female_householder,_no_husband_present = Column(Float)
    E_HH_TYPE_Total_Female_householder_no_husband_present_With_own_children_under_18_years = Column(Float)
    PE_HH_TYPE_Total_Female_householder_no_husband_present_With_own_children_under_18_years = Column(Float)
    E_HH_TYPE_Total_households_Nonfamily_households = Column(Float)
    PE_HH_TYPE_Total_households_Nonfamily_households = Column(Float)
    E_HH_TYPE_Total_households_Nonfamily_households_Householder_living_alone = Column(Float)
    PE_HH_TYPE_Total_households_Nonfamily_households_Householder_living_alone = Column(Float)
    E_HH_TYPE_Total_households_Nonfamily_households_Householder_living_alone_65_years_and_over = Column(Float)
    PE_HH_TYPE_Total_households_Nonfamily_households_Householder_living_alone_65_years_and_over = Column(Float)
    E_HH_TYPE_Total_households_Households_with_one_or_more_people_under_18_years = Column(Float)
    PE_HH_TYPE_Total_households_Households_with_one_or_more_people_under_18_years = Column(Float)
    E_HH_TYPE_Total_households_Households_with_one_or_more_people_65_years_and_over = Column(Float)
    PE_HH_TYPE_Total_households_Households_with_one_or_more_people_65_years_and_over = Column(Float)
    E_HH_TYPE_Total_households_Average_household_size = Column(Float)
    PE_HH_TYPE_Total_households_Average_household_size = Column(Float)
    E_HH_TYPE_Total_households_Average_family_size = Column(Float)
    PE_HH_TYPE_Total_households_Average_family_size = Column(Float)
    E_REL_Population_in_households = Column(Float)
    PE_REL_Population_in_households = Column(Float)
    E_REL_Population_in_households_Householder = Column(Float)
    PE_REL_Population_in_households_Householder = Column(Float)
    E_REL_Population_in_households_Spouse = Column(Float)
    PE_REL_Population_in_households_Spouse = Column(Float)
    E_REL_Population_in_households_Child = Column(Float)
    PE_REL_Population_in_households_Child = Column(Float)
    E_REL_Population_in_households_Other_relatives = Column(Float)
    PE_REL_Population_in_households_Other_relatives = Column(Float)
    E_REL_Population_in_households_Nonrelatives = Column(Float)
    PE_REL_Population_in_households_Nonrelatives = Column(Float)
    E_REL_Population_in_households_Nonrelatives_Unmarried_partner = Column(Float)
    PE_REL_Population_in_households_Nonrelatives_Unmarried_partner = Column(Float)
    E_MARITAL_Males_15_years_and_over = Column(Float)
    PE_MARITAL_Males_15_years_and_over = Column(Float)
    E_MARITAL_Males_15_years_and_over_Never_married = Column(Float)
    PE_MARITAL_Males_15_years_and_over_Never_married = Column(Float)
    E_MARITAL_Males_15_years_and_over_Now_married,_except_separated = Column(Float)
    PE_MARITAL_Males_15_years_and_over_Now_married,_except_separated = Column(Float)
    E_MARITAL_Males_15_years_and_over_Separated = Column(Float)
    PE_MARITAL_Males_15_years_and_over_Separated = Column(Float)
    E_MARITAL_Males_15_years_and_over_Widowed = Column(Float)
    PE_MARITAL_Males_15_years_and_over_Widowed = Column(Float)
    E_MARITAL_Males_15_years_and_over_Divorced = Column(Float)
    PE_MARITAL_Males_15_years_and_over_Divorced = Column(Float)
    E_MARITAL_Females_15_years_and_over = Column(Float)
    PE_MARITAL_Females_15_years_and_over = Column(Float)
    E_MARITAL_Females_15_years_and_over_Never_married = Column(Float)
    PE_MARITAL_Females_15_years_and_over_Never_married = Column(Float)
    E_MARITAL_Females_15_years_and_over_Now_married,_except_separated = Column(Float)
    PE_MARITAL_Females_15_years_and_over_Now_married,_except_separated = Column(Float)
    E_MARITAL_Females_15_years_and_over_Separated = Column(Float)
    PE_MARITAL_Females_15_years_and_over_Separated = Column(Float)
    E_MARITAL_Females_15_years_and_over_Widowed = Column(Float)
    PE_MARITAL_Females_15_years_and_over_Widowed = Column(Float)
    E_MARITAL_Females_15_years_and_over_Divorced = Column(Float)
    PE_MARITAL_Females_15_years_and_over_Divorced = Column(Float)
    E_FERTIL_Number_of_women_15_to_50_years_old_who_had_a_birth_in_the_past_12_months = Column(Float)
    PE_FERTIL_Number_of_women_15_to_50_years_old_who_had_a_birth_in_the_past_12_months = Column(Float)
    E_FERTIL_Number_of_women_birth_in_the_past_12_months_Unmarried_women = Column(Float)
    PE_FERTIL_Number_of_women_birth_in_the_past_12_months_Unmarried_women = Column(Float)
    E_FERTIL_Number_of_women_birth_in_the_past_12_months_Unmarried_women = Column(Float)
    PE_FERTIL_Number_of_women_birth_in_the_past_12_months_Unmarried_women = Column(Float)
    E_FERTIL_Number_of_women_birth_in_the_past_12_months_Per_1000_women_15_to_50_years_old = Column(Float)
    PE_FERTIL_Number_of_women_birth_in_the_past_12_months_Per_1000_women_15_to_50_years_old = Column(Float)
    E_FERTIL_Number_of_women_15_to_50_birth_in_the_past_12_months_Per_1000_women_15_to_19_years_old = Column(Float)
    PE_FERTIL_Number_of_women_15_to_50_birth_in_the_past_12_months_Per_1000_women_15_to_19_years_old = Column(Float)
    E_FERTIL_Number_of_women_15_to_50_birth_in_the_past_12_months_Per_1000_women_20_to_34_years_old = Column(Float)
    PE_FERTIL_Number_of_women_15_to_50_birth_in_the_past_12_months_Per_1000_women_20_to_34_years_old = Column(Float)
    E_FERTIL_Number_of_women_15_to_50_birth_in_the_past_12_months_Per_1000_women_35_to_50_years_old = Column(Float)
    PE_FERTIL_Number_of_women_15_to_50_birth_in_the_past_12_months_Per_1000_women_35_to_50_years_old = Column(Float)
    E_GNDPAR_Number_of_grandparents_living_with_own_grandchildren_under_18_years = Column(Float)
    PE_GNDPAR_Number_of_grandparents_living_with_own_grandchildren_under_18_years = Column(Float)
    E_GNDPAR_Number_of_grandparents_living_with_grandchildren_responsible_for_grandchildren = Column(Float)
    PE_GNDPAR_Number_of_grandparents_living_with_grandchildren_responsible_for_grandchildren = Column(Float)
    E_GNDPAR_Number_of_grandparents_living_with_grandchildren_responsible_for_grandchildren_Less_than_1_year = Column(Float)
    PE_GNDPAR_Number_of_grandparents_living_with_grandchildren_responsible_for_grandchildren_Less_than_1_year = Column(Float)
    E_GNDPAR_Number_of_grandparents_living_with_grandchildren_responsible_for_1_or_2_years = Column(Float)
    PE_GNDPAR_Number_of_grandparents_living_with_grandchildren_responsible_for_1_or_2_years = Column(Float)
    E_GNDPAR_Number_of_grandparents_living_with_grandchildren_responsible_for_3_or_4_years = Column(Float)
    PE_GNDPAR_Number_of_grandparents_living_with_grandchildren_responsible_for_3_or_4_years = Column(Float)
    E_GNDPAR_Number_of_grandparents_living_with_grandchildren_responsible_for__5_or_more_years = Column(Float)
    PE_GNDPAR_Number_of_grandparents_living_with_grandchildren__responsible_for_5_or_more_years = Column(Float)
    E_GNDPAR_Number_of_grandparents_responsible_for_grandchildren_under_18_years = Column(Float)
    PE_GNDPAR_Number_of_grandparents_responsible_for_grandchildren_under_18_years = Column(Float)
    E_GNDPAR_Number_of_grandparents_responsible_for_grandchildren_under_18_years_Who_are_female = Column(Float)
    PE_GNDPAR_Number_of_grandparents_responsible_for_grandchildren_under_18_years_Who_are_female = Column(Float)
    E_GNDPAR_Number_of_grandparents_responsible_for_grandchildren_under_18_years_Who_are_married = Column(Float)
    PE_GNDPAR_Number_of_grandparents_responsible_for_grandchildren_under_18_years_Who_are_married = Column(Float)
    E_SCHOOLKIDS_Population_3_years_and_over_enrolled_in_school = Column(Float)
    PE_SCHOOLKIDS_Population_3_years_and_over_enrolled_in_school = Column(Float)
    E_SCHOOLKIDS_Population_3_years_and_over_enrolled_in_school_Nursery_school,_preschool = Column(Float)
    PE_SCHOOLKIDS_Population_3_years_and_over_enrolled_in_school_Nursery_school,_preschool = Column(Float)
    E_SCHOOLKIDS_Population_3_years_and_over_enrolled_in_school_Kindergarten = Column(Float)
    PE_SCHOOLKIDS_Population_3_years_and_over_enrolled_in_school_Kindergarten = Column(Float)
    E_SCHOOLKIDS_Population_3_years_and_over_enrolled_in_school_Elementary_school_Grades_1_8 = Column(Float)
    PE_SCHOOLKIDS_Population_3_years_and_over_enrolled_in_school_Elementary_school_grades_1_8 = Column(Float)
    E_SCHOOLKIDS_Population_3_years_and_over_enrolled_in_school_High_school_grades_9_12 = Column(Float)
    PE_SCHOOLKIDS_Population_3_years_and_over_enrolled_in_school_High_school_grades_9_12 = Column(Float)
    E_SCHOOLKIDS_Population_3_years_and_over_enrolled_in_school_College_or_graduate_school = Column(Float)
    PE_SCHOOLKIDS_Population_3_years_and_over_enrolled_in_school_College_or_graduate_school = Column(Float)
    E_ED_Population_25_years_and_over = Column(Float)
    PE_ED_Population_25_years_and_over = Column(Float)
    E_ED_Population_25_years_and_over_Less_than_9th_grade = Column(Float)
    PE_ED_Population_25_years_and_over_Less_than_9th_grade = Column(Float)
    E_ED_Population_25_years_and_over_9th_to_12th_grade,_no_diploma = Column(Float)
    PE_ED_Population_25_years_and_over_9th_to_12th_grade,_no_diploma = Column(Float)
    E_ED_Population_25_years_and_over_High_school_graduate_includes_equivalency = Column(Float)
    PE_ED_Population_25_years_and_over_High_school_graduate_includes_equivalency = Column(Float)
    E_ED_Population_25_years_and_over_Some_college,_no_degree = Column(Float)
    PE_ED_Population_25_years_and_over_Some_college,_no_degree = Column(Float)
    E_ED_Population_25_years_and_over_Associates_degree = Column(Float)
    PE_ED_Population_25_years_and_over_Associates_degree = Column(Float)
    E_ED_Population_25_years_and_over_Bachelors_degree = Column(Float)
    PE_ED_Population_25_years_and_over_Bachelors_degree = Column(Float)
    E_ED_Population_25_years_and_over_Graduate_or_professional_degree = Column(Float)
    PE_ED_Population_25_years_and_over_Graduate_or_professional_degree = Column(Float)
    E_ED_Population_25_years_and_over_High_school_graduate_or_higher = Column(Float)
    PE_ED_Population_25_years_and_over_High_school_graduate_or_higher = Column(Float)
    E_ED_Population_25_years_and_over_Bachelors_degree_or_higher = Column(Float)
    PE_ED_Population_25_years_and_over_Bachelors_degree_or_higher = Column(Float)
    E_VETSTAT_Civilian_population_18_years_and_over = Column(Float)
    PE_VETSTAT_Civilian_population_18_years_and_over = Column(Float)
    E_VETSTAT_Civilian_population_18_years_and_over_Civilian_veterans = Column(Float)
    PE_VETSTAT_Civilian_population_18_years_and_over_Civilian_veterans = Column(Float)
    E_DISABILITY_Total_Civilian_Noninstitutionalized_Population = Column(Float)
    PE_DISABILITY_Total_Civilian_Noninstitutionalized_Population = Column(Float)
    E_DISABILITY_Total_Civilian_Noninstitutionalized_Population_With_a_disability = Column(Float)
    PE_DISABILITY_Total_Civilian_Noninstitutionalized_Population_With_a_disability = Column(Float)
    E_DISABILITY_Under_18_years = Column(Float)
    PE_DISABILITY_Under_18_years = Column(Float)
    E_DISABILITY_Under_18_years_With_a_disability = Column(Float)
    PE_DISABILITY_Under_18_years_With_a_disability = Column(Float)
    E_DISABILITY_18_to_64_years = Column(Float)
    PE_DISABILITY_18_to_64_years = Column(Float)
    E_DISABILITY_18_to_64_years_With_a_disability = Column(Float)
    PE_DISABILITY_18_to_64_years_With_a_disability = Column(Float)
    E_DISABILITY_65_years_and_over = Column(Float)
    PE_DISABILITY_65_years_and_over = Column(Float)
    E_DISABILITY_65_years_and_over_With_a_disability = Column(Float)
    PE_DISABILITY_65_years_and_over_With_a_disability = Column(Float)
    E_RES_1_YEAR_AGO_Population_1_year_and_over = Column(Float)
    PE_RES_1_YEAR_AGO_Population_1_year_and_over = Column(Float)
    E_RES_1_YEAR_AGO_Population_1_year_and_over_Same_house = Column(Float)
    PE_RES_1_YEAR_AGO_Population_1_year_and_over_Same_house = Column(Float)
    E_RES_1_YEAR_AGO_Population_1_year_and_over_Different_house_in_the_US = Column(Float)
    PE_RES_1_YEAR_AGO_Population_1_year_and_over_Different_house_in_the_US = Column(Float)
    E_RES_1_YEAR_AGO_Population_1_year_and_over_Different_house_in_the_US_Same_county = Column(Float)
    PE_RES_1_YEAR_AGO_Population_1_year_and_over_Different_house_in_the_US_Same_county = Column(Float)
    E_RES_1_YEAR_AGO_Population_1_year_and_over_Different_house_in_the_US_Different_county = Column(Float)
    PE_RES_1_YEAR_AGO_Population_1_year_and_over_Different_house_in_the_US_Different_county = Column(Float)
    E_RES_1_YEAR_AGO_Population_1_year_and_over_Different_house_in_the_US_Different_county_Same_state = Column(Float)
    PE_RES_1_YEAR_AGO_Population_1_year_and_over_Different_house_in_the_US_Different_county_Same_state = Column(Float)
    E_RES_1_YEAR_AGO_Population_1_year_and_over_Different_house_in_the_US_Different_county_Different_state = Column(Float)
    PE_RES_1_YEAR_AGO_Population_1_year_and_over_Different_house_in_the_US_Different_county_Different_state = Column(Float)
    E_RES_1_YEAR_AGO_Population_1_year_and_over_Abroad = Column(Float)
    PE_RES_1_YEAR_AGO_Population_1_year_and_over_Abroad = Column(Float)
    E_BIRTHPLACE_Total_population = Column(Float)
    PE_BIRTHPLACE_Total_population = Column(Float)
    E_BIRTHPLACE_Total_population_Native = Column(Float)
    PE_BIRTHPLACE_Total_population_Native = Column(Float)
    E_BIRTHPLACE_Total_population_Native_Born_in_United_States = Column(Float)
    PE_BIRTHPLACE_Total_population_Native_Born_in_United_States = Column(Float)
    E_BIRTHPLACE_Total_population_Native_Born_in_United_States_State_of_residence = Column(Float)
    PE_BIRTHPLACE_Total_population_Native_Born_in_United_States_State_of_residence = Column(Float)
    E_BIRTHPLACE_Total_population_Native_Born_in_United_States_Different_state = Column(Float)
    PE_BIRTHPLACE_Total_population_Native_Born_in_United_States_Different_state = Column(Float)
    E_BIRTHPLACE_Total_population_Native_Born_in_Puerto_Rico,_US_Island_areas,_or_born_abroad_to_American_parents = Column(Float)
    PE_BIRTHPLACE_Total_population_Native_Born_in_Puerto_Rico,_US_Island_areas,_or_born_abroad_to_American_parents = Column(Float)
    E_BIRTHPLACE_Total_population_Foreign_born = Column(Float)
    PE_BIRTHPLACE_Total_population_Foreign_born = Column(Float)
    E_CITSTAT_Foreign_born_population = Column(Float)
    PE_CITSTAT_Foreign_born_population = Column(Float)
    E_CITSTAT_Foreign_born_population_Naturalized_US_citizen = Column(Float)
    PE_CITSTAT_Foreign_born_population_Naturalized_US_citizen = Column(Float)
    E_CITSTAT_Foreign_born_population_Not_a_US_citizen = Column(Float)
    PE_CITSTAT_Foreign_born_population_Not_a_US_citizen = Column(Float)
    E_YEARENTERED_Population_born_outside_the_United_States = Column(Float)
    PE_YEARENTERED_Population_born_outside_the_United_States = Column(Float)
    E_YEARENTERED_Population_born_outside_the_United_States_Native = Column(Float)
    PE_YEARENTERED_Population_born_outside_the_United_States_Native = Column(Float)
    E_YEARENTERED_Population_born_outside_the_United_States_Native_Entered_2010_or_later = Column(Float)
    PE_YEARENTERED_Population_born_outside_the_United_States_Native_Entered_2010_or_later = Column(Float)
    E_YEARENTERED_Population_born_outside_the_United_States_Native_Entered_before_2010 = Column(Float)
    PE_YEARENTERED_Population_born_outside_the_United_States_Native_Entered_before_2010 = Column(Float)
    E_YEARENTERED_Population_born_outside_the_United_States_Foreign_born = Column(Float)
    PE_YEARENTERED_Population_born_outside_the_United_States_Foreign_born = Column(Float)
    E_YEARENTERED_Population_born_outside_the_United_States_Foreign_born_Entered_2010_or_later = Column(Float)
    PE_YEARENTERED_Population_born_outside_the_United_States_Foreign_born_Entered_2010_or_later = Column(Float)
    E_YEARENTERED_Population_born_outside_the_United_States_Foreign_born_Entered_before_2010 = Column(Float)
    PE_YEARENTERED_Population_born_outside_the_United_States_Foreign_born_Entered_before_2010 = Column(Float)
    E_REGIONBORN_Foreign_born_population,_excluding_population_born_at_sea = Column(Float)
    PE_REGIONBORN_Foreign_born_population,_excluding_population_born_at_sea = Column(Float)
    PE_REGIONBORN_Foreign_born_population,_excluding_population_born_at_sea_Europe = Column(Float)
    E_REGIONBORN_Foreign_born_population,_excluding_population_born_at_sea_Asia = Column(Float)
    PE_REGIONBORN_Foreign_born_population,_excluding_population_born_at_sea_Asia = Column(Float)
    E_REGIONBORN_Foreign_born_population,_excluding_population_born_at_sea_Africa = Column(Float)
    PE_REGIONBORN_Foreign_born_population,_excluding_population_born_at_sea_Africa = Column(Float)
    E_REGIONBORN_Foreign_born_population,_excluding_population_born_at_sea_Oceania = Column(Float)
    PE_REGIONBORN_Foreign_born_population,_excluding_population_born_at_sea_Oceania = Column(Float)
    E_REGIONBORN_Foreign_born_population,_excluding_population_born_at_sea_Latin_America = Column(Float)
    Foreign_born_population,_excluding_population_born_at_sea_Latin_America = Column(Float)
    Foreign_born_population,_excluding_population_born_at_sea_Northern_America = Column(Float)
    Foreign_born_population,_excluding_population_born_at_sea_Northern_America = Column(Float)
    Population_5_years_and_over = Column(Float)
    Population_5_years_and_over = Column(Float)
    Population_5_years_and_over_English_only = Column(Float)
    Population_5_years_and_over_English_only = Column(Float)
    Population_5_years_and_over_Language_other_than_English = Column(Float)
    Population_5_years_and_over_Language_other_than_English = Column(Float)
    Population_5_years_and_over_Language_other_than_English_Speak_English_less_than_very_well = Column(Float)
    Population_5_years_and_over_Language_other_than_English_Speak_English_less_than_very_well = Column(Float)
    Population_5_years_and_over_Spanish = Column(Float)
    Population_5_years_and_over_Spanish = Column(Float)
    Population_5_years_and_over_Spanish_Speak_English_less_than_very_well = Column(Float)
    Population_5_years_and_over_Spanish_Speak_English_less_than_very_well = Column(Float)
    Population_5_years_and_over_Other_Indo_European_languages = Column(Float)
    Population_5_years_and_over_Other_Indo_European_languages = Column(Float)
    Population_5_years_and_over_Other_Indo_European_languages_Speak_English_less_than_very_well = Column(Float)
    Population_5_years_and_over_Other_Indo_European_languages_Speak_English_less_than_very_well = Column(Float)
    Population_5_years_and_over_Asian_and_Pacific_Islander_languages = Column(Float)
    Population_5_years_and_over_Asian_and_Pacific_Islander_languages = Column(Float)
    Population_5_years_and_over_Asian_and_Pacific_Islander_languages_Speak_English_less_than_very_well = Column(Float)
    Population_5_years_and_over_Asian_and_Pacific_Islander_languages_Speak_English_less_than_very_well = Column(Float)
    Population_5_years_and_over_Other_languages = Column(Float)
    Population_5_years_and_over_Other_languages = Column(Float)
    Population_5_years_and_over_Other_languages_Speak_English_less_than_very_well = Column(Float)
    Population_5_years_and_over_Other_languages_Speak_English_less_than_very_well = Column(Float)
    Total_population = Column(Float)
    Total_population = Column(Float)
    Total_population_American = Column(Float)
    Total_population_American = Column(Float)
    Total_population_Arab = Column(Float)
    Total_population_Arab = Column(Float)
    Total_population_Czech = Column(Float)
    Total_population_Czech = Column(Float)
    Total_population_Danish = Column(Float)
    Total_population_Danish = Column(Float)
    Total_population_Dutch = Column(Float)
    Total_population_Dutch = Column(Float)
    Total_population_English = Column(Float)
    Total_population_English = Column(Float)
    Total_population_French_except_Basque = Column(Float)
    Total_population_French_except_Basque = Column(Float)
    Total_population_French_Canadian = Column(Float)
    Total_population_French_Canadian = Column(Float)
    Total_population_German = Column(Float)
    Total_population_Greek = Column(Float)
    Total_population_Greek = Column(Float)
    Total_population_Hungarian = Column(Float)
    Total_population_Hungarian = Column(Float)
    Total_population_Irish = Column(Float)
    Total_population_Irish = Column(Float)
    Total_population_Italian = Column(Float)
    Total_population_Italian = Column(Float)
    Total_population_Lithuanian = Column(Float)
    Total_population_Lithuanian = Column(Float)
    Total_population_Norwegian = Column(Float)
    Total_population_Norwegian = Column(Float)
    Total_population_Polish = Column(Float)
    Total_population_Polish = Column(Float)
    Total_population_Portuguese = Column(Float)
    Total_population_Portuguese = Column(Float)
    Total_population_Russian = Column(Float)
    Total_population_Russian = Column(Float)
    Total_population_Scotch_Irish = Column(Float)
    Total_population_Scotch_Irish = Column(Float)
    Total_population_Scottish = Column(Float)
    Total_population_Scottish = Column(Float)
    Total_population_Slovak = Column(Float)
    Total_population_Slovak = Column(Float)
    Total_population_Subsaharan_African = Column(Float)
    Total_population_Subsaharan_African = Column(Float)
    Total_population_Swedish = Column(Float)
    Total_population_Swedish = Column(Float)
    Total_population_Swiss = Column(Float)
    Total_population_Swiss = Column(Float)
    Total_population_Ukrainian = Column(Float)
    Total_population_Ukrainian = Column(Float)
    Total_population_Welsh = Column(Float)
    Total_population_Welsh = Column(Float)
    Total_population_West_Indian_excluding_Hispanic_origin_groups = Column(Float)
    Total_population_West_Indian_excluding_Hispanic_origin_groups = Column(Float)
    Total_households = Column(Float)
    Total_households = Column(Float)
    households_With_a_computer = Column(Float)
    households_With_a_computer = Column(Float)
    households_With_a_broadband_Internet_subscription = Column(Float)
    households_With_a_broadband_Internet_subscription = Column(Float)
   


class Meta_Data(Base):
    __tablename__ = 'Meta_Data'
    Code = Column(String(255), primary_key=True)
    TableCode = Column(String(255))
    ColumnCode = Column(String(255))
    ColumnNumber = Column(String(255))
    ColumnNumeric = Column(String(255))
    ColumnLetter = Column(String(255))
    ColumnTitle = Column(String(255))
    
class Race_Data(Base):
    __tablename__ = 'Race_Data'
    GEO_ID = Column(String(255), primary_key=True)
    FIPS_CODE = Column(Integer)
    NAME = Column(String(255))
    TRACT_NAME = Column(String(255))
    COUNTY = Column(String(255))
    STATE = Column(String(255))
    Households = Column(Float)
    Total_Households_Race_Hispanic_Latino_White_alone = Column(Float)
    Computer_Broadband_Households_Race_Hispanic_Latino_White_alone = Column(Float)
    PrecentComputer_Broadband_Households_Race_Hispanic_Latino_White_alone = Column(Float)
    Computer_NoInternet_Households_Race_Hispanic_Latino_White_alone = Column(Float)
    PrecentComputer_NoInternet_Households_Race_Hispanic_Latino_White_alone = Column(Float)
    NoComputer_Households_Race_Hispanic_Latino_White_alone = Column(Float)
    PrecentNoComputer_Households_Race_Hispanic_Latino_White_alone = Column(Float)
    Total_Households_Race_Hispanic_Latino_Black_or_African_American_alone = Column(Float)
    Computer_Broadband_Households_Race_Hispanic_Latino_Black_or_African_American_alone = Column(Float)
    PrecentComputer_Broadband_Households_Race_Hispanic_Latino_Black_or_African_American_alone = Column(Float)
    Computer_NoInternet_Households_Race_Hispanic_Latino_Black_or_African_American_alone = Column(Float)
    PrecentComputer_NoInternet_Households_Race_Hispanic_Latino_Black_or_African_American_alone = Column(Float)
    NoComputer_Households_Race_Hispanic_Latino_Black_or_African_American_alone = Column(Float)
    PrecentNoComputer_Households_Race_Hispanic_Latino_Black_or_African_American_alone = Column(Float)
    Total_Households_Race_Hispanic_Latino_American_Indian_and_Alaska_Native_alone = Column(Float)
    Computer_Broadband_Households_Race_Hispanic_Latino_American_Indian_and_Alaska_Native_alone = Column(Float)
    PrecentComputer_Broadband_Households_Race_Hispanic_Latino_American_Indian_and_Alaska_Native_alone = Column(Float)
    Computer_NoInternet_Households_Race_Hispanic_Latino_American_Indian_and_Alaska_Native_alone = Column(Float)
    PrecentComputer_NoInternet_Households_Race_Hispanic_Latino_American_Indian_and_Alaska_Native_alone = Column(Float)
    NoComputer_Households_Race_Hispanic_Latino_American_Indian_and_Alaska_Native_alone = Column(Float)
    PrecentNoComputer_Households_Race_Hispanic_Latino_American_Indian_and_Alaska_Native_alone = Column(Float)
    Total_Households_Race_Hispanic_Latino_Asian_alone = Column(Float)
    Computer_Broadband_Households_Race_Hispanic_Latino_Asian_alone = Column(Float)
    PrecentComputer_Broadband_Households_Race_Hispanic_Latino_Asian_alone = Column(Float)
    Computer_NoInternet_Households_Race_Hispanic_Latino_Asian_alone = Column(Float)
    PrecentComputer_NoInternet_Households_Race_Hispanic_Latino_Asian_alone = Column(Float)
    NoComputer_Households_Race_Hispanic_Latino_Asian_alone = Column(Float)
    PrecentNoComputer_Households_Race_Hispanic_Latino_Asian_alone = Column(Float)
    Total_Households_Race_Hispanic_Latino_Native_Hawaiian_and_Other_Pacific_Islander_alone = Column(Float)
    Computer_Broadband_Households_Race_Hispanic_Latino_Native_Hawaiian_and_Other_Pacific_Islander_alone = Column(Float)
    PrecentComputer_Broadband_Households_Race_Hispanic_Latino_Native_Hawaiian_and_Other_Pacific_Islander_alone = Column(Float)
    Computer_NoInternet_Households_Race_Hispanic_Latino_Native_Hawaiian_and_Other_Pacific_Islander_alone = Column(Float)
    PrecentComputer_NoInternet_Households_Race_Hispanic_Latino_Native_Hawaiian_and_Other_Pacific_Islander_alone = Column(Float)
    NoComputer_Households_Race_Hispanic_Latino_Native_Hawaiian_and_Other_Pacific_Islander_alone = Column(Float)
    PrecentNoComputer_Households_Race_Hispanic_Latino_Native_Hawaiian_and_Other_Pacific_Islander_alone = Column(Float)
    Total_Households_Race_Hispanic_Latino_Some_other_race_alone = Column(Float)
    Computer_Broadband_Households_Race_Hispanic_Latino_Some_other_race_alone = Column(Float)
    PrecentComputer_Broadband_Households_Race_Hispanic_Latino_Some_other_race_alone = Column(Float)
    Computer_NoInternet_Households_Race_Hispanic_Latino_Some_other_race_alone = Column(Float)
    PrecentComputer_NoInternet_Households_Race_Hispanic_Latino_Some_other_race_alone = Column(Float)
    NoComputer_Households_Race_Hispanic_Latino_Some_other_race_alone = Column(Float)
    PrecentNoComputer_Households_Race_Hispanic_Latino_Some_other_race_alone = Column(Float)
    Total_Households_Race_Hispanic_Latino_Two_or_more_races = Column(Float)
    Computer_Broadband_Households_Race_Hispanic_Latino_Two_or_more_races = Column(Float)
    PrecentComputer_Broadband_Households_Race_Hispanic_Latino_Two_or_more_races = Column(Float)
    Computer_NoInternet_Households_Race_Hispanic_Latino_Two_or_more_races = Column(Float)
    PrecentComputer_NoInternet_Households_Race_Hispanic_Latino_Two_or_more_races = Column(Float)
    NoComputer_Households_Race_Hispanic_Latino_Two_or_more_races = Column(Float)
    PrecentNoComputer_Households_Race_Hispanic_Latino_Two_or_more_races = Column(Float)
    Total_Households_Race_Hispanic_Latino_Hispanic_or_Latino_origin_of_any_race = Column(Float)
    Computer_Broadband_Households_Race_Hispanic_Latino_Hispanic_or_Latino_origin_of_any_race = Column(Float)
    PrecentComputer_Broadband_Households_Race_Hispanic_Latino_Hispanic_or_Latino_origin_of_any_race = Column(Float)
    Computer_NoInternet_Households_Race_Hispanic_Latino_Hispanic_or_Latino_origin_of_any_race = Column(Float)
    PrecentComputer_NoInternet_Households_Race_Hispanic_Latino_Hispanic_or_Latino_origin_of_any_race = Column(Float)
    NoComputer_Households_Race_Hispanic_Latino_Hispanic_or_Latino_origin_of_any_race = Column(Float)
    PrecentNoComputer_Households_Race_Hispanic_Latino_Hispanic_or_Latino_origin_of_any_race = Column(Float)
    Total_Households_Race_Hispanic_Latino_White_alone,_not_Hispanic_or_Latino = Column(Float)
    Computer_Broadband_Households_Race_Hispanic_Latino_White_alone,_not_Hispanic_or_Latino = Column(Float)
    PrecentComputer_Broadband_Households_Race_Hispanic_Latino_White_alone,_not_Hispanic_or_Latino = Column(Float)
    Computer_NoInternet_Households_Race_Hispanic_Latino_White_alone,_not_Hispanic_or_Latino = Column(Float)
    PrecentComputer_NoInternet_Households_Race_Hispanic_Latino_White_alone,_not_Hispanic_or_Latino = Column(Float)
    NoComputer_Households_Race_Hispanic_Latino_White_alone,_not_Hispanic_or_Latino = Column(Float)
    PrecentNoComputer_Households_Race_Hispanic_Latino_White_alone,_not_Hispanic_or_Latino = Column(Float)
    Total_Households_EDUCATIONAL_ATTAINMENT_25_years_and_over = Column(Float)
    Computer_Broadband_Households_EDUCATIONAL_ATTAINMENT_25_years_and_over = Column(Float)
    PrecentComputer_Broadband_Households_EDUCATIONAL_ATTAINMENT_25_years_and_over = Column(Float)
    Computer_NoInternet_Households_EDUCATIONAL_ATTAINMENT_25_years_and_over = Column(Float)
    PrecentComputer_NoInternet_Households_EDUCATIONAL_ATTAINMENT_25_years_and_over = Column(Float)
    NoComputer_Households_EDUCATIONAL_ATTAINMENT_Household_population_25_years_and_over = Column(Float)
    PrecentNoComputer_Households_EDUCATIONAL_ATTAINMENT_Household_population_25_years_and_over = Column(Float)
    Total_Households_EDUCATIONAL_ATTAINMENT_Household_population_25_years_and_over_Less_than_high_school_graduate_or_equivalency = Column(Float)
    Computer_Broadband_Households_EDUCATIONAL_ATTAINMENT_Household_population_25_years_and_over_Less_than_high_school_graduate_or_equivalency = Column(Float)
    PrecentComputer_Broadband_Households_EDUCATIONAL_ATTAINMENT_Household_population_25_years_and_over_Less_than_high_school_graduate_or_equivalency = Column(Float)
    Computer_NoInternet_Households_EDUCATIONAL_ATTAINMENT_Household_population_25_years_and_over_Less_than_high_school_graduate_or_equivalency = Column(Float)
    PrecentComputer_NoInternet_Households_EDUCATIONAL_ATTAINMENT_Household_population_25_years_and_over_Less_than_high_school_graduate_or_equivalency = Column(Float)
    NoComputer_Households_EDUCATIONAL_ATTAINMENT_Household_population_25_years_and_over_Less_than_high_school_graduate_or_equivalency = Column(Float)
    PrecentNoComputer_Households_EDUCATIONAL_ATTAINMENT_Household_population_25_years_and_over_Less_than_high_school_graduate_or_equivalency = Column(Float)
    Total_Households_EDUCATIONAL_ATTAINMENT_Household_population_25_years_and_over_High_school_graduate_includes_equivalency_some_college_or_associates_degree = Column(Float)
    Computer_Broadband_Households_EDUCATIONAL_ATTAINMENT_Household_population_25_years_and_over_High_school_graduate_includes_equivalency_some_college_or_associates_degree = Column(Float)
    PrecentComputer_Broadband_Households_EDUCATIONAL_ATTAINMENT_Household_population_25_years_and_over_High_school_graduate_includes_equivalency_some_college_or_associates_degree = Column(Float)
    Computer_NoInternet_Households_EDUCATIONAL_ATTAINMENT_Household_population_25_years_and_over_High_school_graduate_includes_equivalency_some_college_or_associates_degree = Column(Float)
    PrecentComputer_NoInternet_Households_EDUCATIONAL_ATTAINMENT_Household_population_25_years_and_over_High_school_graduate_includes_equivalency_some_college_or_associates_degree = Column(Float)
    NoComputer_Households_EDUCATIONAL_ATTAINMENT_Household_population_25_years_and_over_High_school_graduate_includes_equivalency_some_college_or_associates_degree = Column(Float)
    PrecentNoComputer_Households_EDUCATIONAL_ATTAINMENT_Household_population_25_years_and_over_High_school_graduate_includes_equivalency_some_college_or_associates_degree = Column(Float)
    Total_Households_EDUCATIONAL_ATTAINMENT_Household_population_25_years_and_over_Bachelors_degree_or_higher = Column(Float)
    Computer_Broadband_Households_EDUCATIONAL_ATTAINMENT_Household_population_25_years_and_over_Bachelors_degree_or_higher = Column(Float)
    PrecentComputer_Broadband_Households_EDUCATIONAL_ATTAINMENT_Household_population_25_years_and_over_Bachelors_degree_or_higher = Column(Float)
    Computer_NoInternet_Households_EDUCATIONAL_ATTAINMENT_Household_population_25_years_and_over_Bachelors_degree_or_higher = Column(Float)
    PrecentComputer_NoInternet_Households_EDUCATIONAL_ATTAINMENT_Household_population_25_years_and_over_Bachelors_degree_or_higher = Column(Float)
    NoComputer_Households_EDUCATIONAL_ATTAINMENT_Household_population_25_years_and_over_Bachelors_degree_or_higher = Column(Float)
    PrecentNoComputer_Households_EDUCATIONAL_ATTAINMENT_Household_population_25_years_and_over_Bachelors_degree_or_higher = Column(Float)
 

class Race_MetaData(Base):
    __tablename__ = 'Race_MateData'
    GEO_ID = Column(String(255), primary_key=True)
    TGEO_ID = Column(String(255))
    id = Column(String(255))
    Filter1 = Column(String(255))
    Filter2 = Column(String(255))
    Filter3 = Column(String(255))
    id = Column(String(255))
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-5-7e34c374f4bc> in <module>
#       3
#       4 # Creates Classes which will serve as the anchor points for our Tables
# ----> 5 class Census_Data(Base):
#       6     __tablename__ = 'Census_Data'
#       7     GEO_ID = Column(String(255), primary_key=True)
#
# <ipython-input-5-7e34c374f4bc> in Census_Data()
#      18     E_HH_TYPE_Total_households_Married_couple_family_With_own_children_under_18_years = Column(Float)
#      19     PE_HH_TYPE_Total_households_Married_couple_family_With_own_children_under_18_years = Column(Float)
# ---> 20     E_HH_TYPE_Total_Male_householder,_no_wife_present = Column(Float)
#      21     PE_HH_TYPE_Total_Male_householder,_no_wife_present = Column(Float)
#      22     E_HH_TYPE_Total_Male_householder,_no_wife_present_With_own_under_18_years = Column(Float)
#
# ...

# %%
# Create a Specific Instance of the Dog and Cat classes
# I am not really sure how to do this. Maybe Steven can help?

'''insert_query = Census_Data.insert()

with open('ACSDP5Y2018-Copy2.DP02_data_with_overlays_2020-07-19T201042', 'r', encoding="utf-8") as csvfile:
    csv_reader = csv.reader(csvfile, delimiter=',')
    engine.execute(
        insert_query, 
            for row in csv_reader {['DP02_0001E';[0]:'DP02_0152PE';[830]]}
    ) '''
# This didn't work. I am trying something else to read in the csv data
# Out:
# 'insert_query = Census_Data.insert()\n\nwith open(\'ACSDP5Y2018-Copy2.DP02_data_with_overlays_2020-07-19T201042\', \'r\', encoding="utf-8") as csvfile:\n    csv_reader = csv.reader(csvfile, delimiter=\',\')\n    engine.execute(\n        insert_query, \n            for row in csv_reader {[\'DP02_0001E\';[0]:\'DP02_0152PE\';[830]]}\n    ) '

# %%
df = pd.read_csv('COLUMN_DATA-Table 1.csv', 'r', encoding="utf-8", error_bad_lines = False)
df.to_sql('Meta_Data', conn, if_exists='replace', index=False)
# Out:
# 2020-07-25 11:52:17,327 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("Meta_Data")
# 2020-07-25 11:52:17,328 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-25 11:52:17,331 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("Meta_Data")
# 2020-07-25 11:52:17,332 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-25 11:52:17,333 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2020-07-25 11:52:17,334 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-25 11:52:17,335 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("Meta_Data")
# 2020-07-25 11:52:17,336 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-25 11:52:17,337 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Meta_Data' AND type = 'table'
# 2020-07-25 11:52:17,337 INFO sqlalchemy.engine.base.Engine ()
# ...

# %%
df = pd.read_csv('CompInt_Race_TblS2802.csv', encoding="utf-8", error_bad_lines = False)
df.to_sql('Race_Data', conn, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1245                     self.dialect.do_execute(
# -> 1246                         cursor, statement, parameters, context
#    1247                     )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     587     def do_execute(self, cursor, statement, parameters, context=None):
# --> 588         cursor.execute(statement, parameters)
#     589
#
# OperationalError: database is locked
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-6-6eb4ba244289> in <module>
# ...

# %%
df.head()
# Out:
#                  GEO_ID    FIPS_CODE                                     NAME  \
# 0  1400000US41001950100  41001950100  Census Tract 9501, Baker County, Oregon
# 1  1400000US41001950200  41001950200  Census Tract 9502, Baker County, Oregon
# 2  1400000US41001950300  41001950300  Census Tract 9503, Baker County, Oregon
# 3  1400000US41001950400  41001950400  Census Tract 9504, Baker County, Oregon
# 4  1400000US41001950500  41001950500  Census Tract 9505, Baker County, Oregon
#
#           TRACT_NAME  COUNTY   STATE  E-Households  \
# 0  Census Tract 9501   Baker  Oregon          2806
# 1  Census Tract 9502   Baker  Oregon          3435
# 2  Census Tract 9503   Baker  Oregon          2419
# 3  Census Tract 9504   Baker  Oregon          2634
# 4  Census Tract 9505   Baker  Oregon          2166
#
#    E-Total-Households-Race_Hispanic_Latino-White alone  \
# 0                                               2659
# 1                                               3247
# ...

# %%
df = pd.read_csv('CompInt_Race_TblS2802_Metadata.csv', 'r', encoding="utf-8", error_bad_lines = False)
df.to_sql('Race_MetaData', conn, if_exists='replace', index=False)

# %%
df = pd.read_csv('ACSDP5Y2018-Copy1.DP02_data_with_overlays_2020-07-19T201042.csv', 'r', encoding="utf-8", error_bad_lines = False)
df.to_sql('Census_Data', conn, if_exists='replace', index=False)
#Create table first? 
#df_New.iloc[144:148]
# Out:
# 2020-07-25 11:52:24,797 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("Census_Data")
# 2020-07-25 11:52:24,797 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-25 11:52:24,804 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("Census_Data")
# 2020-07-25 11:52:24,805 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-25 11:52:24,810 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2020-07-25 11:52:24,811 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-25 11:52:24,812 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("Census_Data")
# 2020-07-25 11:52:24,813 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-25 11:52:24,874 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Census_Data' AND type = 'table'
# 2020-07-25 11:52:24,875 INFO sqlalchemy.engine.base.Engine ()
# ...

# %%
# Create Database Connection
# ----------------------------------
# Creates a connection to our DB
engine = create_engine("sqlite:///Internet_Data.db", echo=False)
conn = engine.connect()

# %%
# Create a "Metadata" Layer That Abstracts our SQL Database
# ----------------------------------
# Create (if not already in existence) the tables associated with our classes.
# Base.metadata.create_all(engine)
results = engine.execute("Select * From Race_Data limit 10")
for result in results:
    print(result[0])
# Use this to clear out the db
# ----------------------------------
# Base.metadata.drop_all(engine)
# Out:
# act_name,county_name,state,E-Households,E-Total-Households-Race_Hispanic_Latino-White alone,E-Compute
# egon",Census T
# egon",Census T
# egon",Census T
# egon",Census T
# egon",Census T
# egon",Census T
# act 1, Benton,O
# act 2.02, Benton,O
# act 4, Benton,O

# %%
# Create a Session Object to Connect to DB
# ----------------------------------
# Session is a temporary binding to our DB
from sqlalchemy.orm import Session
session = Session(bind=engine)

# %%
# Query All Records in the the Database
data = engine.execute("SELECT * FROM Census_Data")

for record in data:
    print(record)
# Out:
# ('id,id,,,,Geog', 'aphic A', 'ea Name,E-HH_TYPE-Total households,PE-HH_TYPE-Total households,E-HH_TYPE-Total households-Family households (families),PE-HH_TYPE-Total households-Family households (families),E-HH_TYPE-Total households-Family households (families)-With own child', 'en of the householde', ' unde', ' 18 yea', 's,PE-HH_TYPE-Total households-Family households (families)-With own child', 'en of the householde', ' unde', ' 18 yea', 's,E-HH_TYPE-Total households-Family households (families)-Ma', None, 'ied-couple family,PE-HH_TYPE-Total households-Family households (families)-Ma', None, 'ied-couple family,E-HH_TYPE-Total households-Family households (families)-Ma', None, 'ied-couple family-With own child', 'en of the householde', ' unde', ' 18 yea', 's,PE-HH_TYPE-Total households-Family households (families)-Ma', None, 'ied-couple family-With own child', 'en of the householde', ' unde', ' 18 yea', 's,"E-HH_TYPE-Total households-Family households (families)-Male householde', ',
# ...
