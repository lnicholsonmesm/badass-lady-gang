# %%
# SQLAlchemy
from sqlalchemy import create_engine

# Imports the methods needed to abstract classes into tables
from sqlalchemy.ext.declarative import declarative_base

# Allow us to declare column types
from sqlalchemy import Table, Column, Integer, String, Float, MetaData

#pandas for data manipulation and export
import pandas as pd

# %%
db_uri = "sqlite:///db.sqlite"
engine = create_engine(db_uri, echo = True)

# %%
df = pd.read_csv("data/S2802.csv", na_values = ["-"])
df = df.astype({"fips_id": "object"})
print(df.dtypes[90:-1])
#df.columns
df
# Out:
# E_Total_Households_EDUATTAINfor25up_Highschoolgraduate(includesequivalency)_somecollegeorassociatesdegree                     int64
# E_Computer_Broadband_Households_EDUATTAINfor25up_Highschoolgraduate(includesequivalency)_somecollegeorassociatesdegree        int64
# PE_Computer_Broadband_Households_EDUATTAINfor25up_Highschoolgraduate(includesequivalency)_somecollegeorassociatesdegree     float64
# E_Computer_NoInternet_Households_EDUATTAINfor25up_Highschoolgraduate(includesequivalency)_somecollegeorassociatesdegree       int64
# PE_Computer_NoInternet_Households_EDUATTAINfor25up_Highschoolgraduate(includesequivalency)_somecollegeorassociatesdegree    float64
# E_NoComputer_Households_EDUATTAINfor25up_Highschoolgraduate(includesequivalency)_somecollegeorassociatesdegree                int64
# PE_NoComputer_Households_EDUATTAINfor25up_Highschoolgraduate(includesequivalency)_somecollegeorassociatesdegree             float64
# E_Total_Households_EDUATTAINfor25up_Bachelorsdegreeorhigher                                                                   int64
# E_Computer_Broadband_Households_EDUATTAINfor25up_Bachelorsdegreeorhigher                                                      int64
# PE_Computer_Broadband_Households_EDUATTAINfor25up_Bachelorsdegreeorhigher                                                   float64
# E_Computer_NoInternet_Households_EDUATTAINfor25up_Bachelorsdegreeorhigher                                                     int64
# PE_Computer_NoInternet_Households_EDUATTAINfor25up_Bachelorsdegreeorhigher                                                  float64
# E_NoComputer_Households__EDUATTAINfor25up_Bachelorsdegreeorhigher                                                             int64
# dtype: object
#                        id      fips_id  \
# 0    1400000US41001950100  41001950100
# 1    1400000US41001950200  41001950200
# 2    1400000US41001950300  41001950300
# 3    1400000US41001950400  41001950400
# 4    1400000US41001950500  41001950500
# ..                    ...          ...
# 829  1400000US41071030702  41071030702
# 830  1400000US41071030801  41071030801
# 831  1400000US41071030802  41071030802
# 832  1400000US41071030900  41071030900
# 833  1400000US41071031000  41071031000
#
#                               GeographicAreaName           tract_name  \
# 0        Census Tract 9501, Baker County, Oregon    Census Tract 9501
# 1        Census Tract 9502, Baker County, Oregon    Census Tract 9502
# 2        Census Tract 9503, Baker County, Oregon    Census Tract 9503
# 3        Census Tract 9504, Baker County, Oregon    Census Tract 9504
# 4        Census Tract 9505, Baker County, Oregon    Census Tract 9505
# ..                                           ...                  ...
# 829  Census Tract 307.02, Yamhill County, Oregon  Census Tract 307.02
# 830  Census Tract 308.01, Yamhill County, Oregon  Census Tract 308.01
# 831  Census Tract 308.02, Yamhill County, Oregon  Census Tract 308.02
# 832     Census Tract 309, Yamhill County, Oregon     Census Tract 309
# 833     Census Tract 310, Yamhill County, Oregon     Census Tract 310
#
#     county_name   state  E_Households  \
# 0         Baker  Oregon          2806
# 1         Baker  Oregon          3435
# 2         Baker  Oregon          2419
# 3         Baker  Oregon          2634
# 4         Baker  Oregon          2166
# ..          ...     ...           ...
# 829     Yamhill  Oregon          7347
# 830     Yamhill  Oregon          5311
# 831     Yamhill  Oregon          3914
# 832     Yamhill  Oregon          4829
# 833     Yamhill  Oregon          4140
#
#      E_Total_Households_Race_Hispanic_Latino_Whitealone  \
# 0                                                 2659
# 1                                                 3247
# 2                                                 2244
# 3                                                 2413
# 4                                                 1982
# ..                                                 ...
# 829                                               6534
# 830                                               4429
# 831                                               3008
# 832                                               4285
# 833                                               3639
#
#      E_Computer_Broadband_Totalhouseholds  \
# 0                                    2020
# 1                                    2764
# 2                                    1943
# 3                                    2100
# 4                                    1751
# ..                                    ...
# 829                                  6044
# 830                                  4266
# 831                                  3199
# 832                                  4175
# 833                                  3435
#
#      E_Computer_Broadband_Households_Race_Hispanic_Latino_Whitealone  ...  \
# 0                                                 1887                ...
# 1                                                 2685                ...
# 2                                                 1772                ...
# 3                                                 1979                ...
# 4                                                 1567                ...
# ..                                                 ...                ...
# 829                                               5248                ...
# 830                                               3634                ...
# 831                                               2309                ...
# 832                                               3660                ...
# 833                                               3084                ...
#
#      PE_Computer_NoInternet_Households_EDUATTAINfor25up_Highschoolgraduate(includesequivalency)_somecollegeorassociatesdegree  \
# 0                                                 18.1
# 1                                                 12.4
# 2                                                 11.2
# 3                                                 10.4
# 4                                                 18.9
# ..                                                 ...
# 829                                                9.3
# 830                                               12.8
# 831                                               12.7
# 832                                                7.7
# 833                                                8.5
#
#      E_NoComputer_Households_EDUATTAINfor25up_Highschoolgraduate(includesequivalency)_somecollegeorassociatesdegree  \
# 0                                                  122
# 1                                                  226
# 2                                                  207
# 3                                                  197
# 4                                                   88
# ..                                                 ...
# 829                                                253
# 830                                                326
# 831                                                123
# 832                                                 59
# 833                                                131
#
#      PE_NoComputer_Households_EDUATTAINfor25up_Highschoolgraduate(includesequivalency)_somecollegeorassociatesdegree  \
# 0                                                  8.0
# 1                                                 14.6
# 2                                                 18.3
# 3                                                 14.4
# 4                                                  9.2
# ..                                                 ...
# 829                                                8.0
# 830                                               15.8
# 831                                                8.3
# 832                                                2.9
# 833                                                6.6
#
#      E_Total_Households_EDUATTAINfor25up_Bachelorsdegreeorhigher  \
# 0                                                  449
# 1                                                  661
# 2                                                  231
# 3                                                  493
# 4                                                  429
# ..                                                 ...
# 829                                               1053
# 830                                                557
# 831                                                291
# 832                                                731
# 833                                                673
#
#      E_Computer_Broadband_Households_EDUATTAINfor25up_Bachelorsdegreeorhigher  \
# 0                                                  419
# 1                                                  607
# 2                                                  224
# 3                                                  424
# 4                                                  403
# ..                                                 ...
# 829                                                936
# 830                                                486
# 831                                                261
# 832                                                678
# 833                                                589
#
#      PE_Computer_Broadband_Households_EDUATTAINfor25up_Bachelorsdegreeorhigher  \
# 0                                                 93.3
# 1                                                 91.8
# 2                                                 97.0
# 3                                                 86.0
# 4                                                 93.9
# ..                                                 ...
# 829                                               88.9
# 830                                               87.3
# 831                                               89.7
# 832                                               92.7
# 833                                               87.5
#
#      E_Computer_NoInternet_Households_EDUATTAINfor25up_Bachelorsdegreeorhigher  \
# 0                                                    1
# 1                                                   14
# 2                                                    0
# 3                                                   36
# 4                                                   16
# ..                                                 ...
# 829                                                 69
# 830                                                 49
# 831                                                 22
# 832                                                 40
# 833                                                 69
#
#      PE_Computer_NoInternet_Households_EDUATTAINfor25up_Bachelorsdegreeorhigher  \
# 0                                                  0.2
# 1                                                  2.1
# 2                                                  0.0
# 3                                                  7.3
# 4                                                  3.7
# ..                                                 ...
# 829                                                6.6
# 830                                                8.8
# 831                                                7.6
# 832                                                5.5
# 833                                               10.3
#
#      E_NoComputer_Households__EDUATTAINfor25up_Bachelorsdegreeorhigher  \
# 0                                                   27
# 1                                                   40
# 2                                                    7
# 3                                                   33
# 4                                                   10
# ..                                                 ...
# 829                                                 48
# 830                                                 22
# 831                                                  8
# 832                                                 13
# 833                                                 15
#
#      PE_NoComputer_Households__EDUATTAINfor25up_Bachelorsdegreeorhigher
# 0                                                  6.0
# 1                                                  6.1
# 2                                                  3.0
# 3                                                  6.7
# 4                                                  2.3
# ..                                                 ...
# 829                                                4.6
# 830                                                3.9
# 831                                                2.7
# 832                                                1.8
# 833                                                2.2
#
# [834 rows x 104 columns]

# %%
df.PE_NoComputer_Households__EDUATTAINfor25up_Bachelorsdegreeorhigher.dtype
# Out:
# dtype('float64')

# %%
df.to_sql("s2802", con=engine, if_exists="replace", index_label=None)

# %%
engine.execute("SELECT * FROM s2802 LIMIT 2").fetchall()
# Out:
# 2020-07-24 23:12:05,339 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-07-24 23:12:05,340 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-24 23:12:05,343 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-07-24 23:12:05,345 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-24 23:12:05,348 INFO sqlalchemy.engine.base.Engine SELECT * FROM s2802 LIMIT 2
# 2020-07-24 23:12:05,350 INFO sqlalchemy.engine.base.Engine ()
# [(0, '1400000US41001950100', 41001950100, 'Census Tract 9501, Baker County, Oregon', 'Census Tract 9501', ' Baker', 'Oregon', 2806, 2659, 2020, 1887, 72.0, 71.0, 555, 541, 19.8, 20.3, 199, 199, 7.1, 7.5, 26, 26, 100.0, 0, 0.0, 0, 0.0, 24, 24, 100.0, 0, 0.0, 0, 0.0, 22, 22, 100.0, 0, 0.0, 0, 0.0, 9, 2, 22.2, 7, 77.8, 0, 0.0, 47, 47, 100.0, 0, 0.0, 0, 0.0, 19, 12, 63.2, 7, 36.8, 0, 0.0, 161, 79, 49.1, 82, 50.9, 0, 0.0, 2535, 1843, 72.7, 461, 18.2, 199, 7.9, 2217, 1614, 72.8, 372, 16.8, 199, 9.0, 249, 103, 41.4, 96, 38.6, 50, 20.1, 1519, 1092, 71.9, 275, 18.1, 122, 8.0, 449, 419, 93.3, 1, 0.2, 27, 6.0),
#  (1, '1400000US41001950200', 41001950200, 'Census Tract 9502, Baker County, Oregon', 'Census Tract 9502', ' Baker', 'Oregon', 3435, 3247, 2764, 2685, 80.5, 82.7, 255, 238, 7.4, 7.3, 416, 324, 12.1, 10.0, 25, 21, 84.0, 4, 16.0, 0, 0.0, 41, 41, 100.0, 0, 0.0, 0, 0.0, 0, 0, None, 0, None, 0, None, 0, 0, None, 0, None, 0, None, 99, 8, 8.1, 13, 13.1, 78, 78.8, 23, 9, 39.1, 0, 0.0, 14, 60.9, 133, 31, 23.3, 13, 9.8, 89, 66.9, 3210, 2659, 82.8, 238, 7.4, 313, 9.8, 2374, 1800, 75.8, 210, 8.8, 364, 15.3, 164, 62, 37.8, 4, 2.4, 98, 59.8, 1549, 1131, 73.0, 192, 12.4, 226, 14.6, 661, 607, 91.8, 14, 2.1, 40, 6.1)]
