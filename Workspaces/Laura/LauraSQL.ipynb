# %%
# SQLAlchemy
from sqlalchemy import create_engine

# Imports the methods needed to abstract classes into tables
from sqlalchemy.ext.declarative import declarative_base

# Allow us to declare column types
from sqlalchemy import Table, Column, Integer, String, Float, MetaData

#pandas for data manipulation and export
import pandas as pd

# %%
engine = create_engine('sqlite:///Dashboard.db', echo = True)

# %%
engine = create_engine('sqlite:///Internet_Data.db', echo = True)
#engine = create_engine('sqlite:///Census_Data.sqlite', echo = True)

# %% [markdown]
# table_names() -- get table names
# execute() -- executes sql

# %%
# Sets an object to utilize the default declarative base in SQL Alchemy
Base = declarative_base()
meta = MetaData()

# %% [markdown]
# S2802 = Table(
#    's2802', meta,
#    Column('id', Integer, primary_key = True),
#    Column('name', String),
#    Column('lastname', String),
# )

# %%
S2802 = Table(
    's2802', meta, 
    Column('id', String),
    Column('fips_id', String),
    Column('GeographicAreaName', String),
    Column('tract_name', String),
    Column('county_name', String),
    Column('state', String),
    Column('E-Households', Float),
    Column('E-Total-Households-Race_Hispanic_Latino-Whitealone', Float),
    Column('E-Computer-Broadband-Totalhouseholds', Float),
    Column('E-Computer-Broadband-Households-Race_Hispanic_Latino-Whitealone', Float),
    Column('PE-Computer-Broadband-Household', Float),
    Column('PE-Computer-Broadband-Households-Race_Hispanic_Latino-Whitealone', Float),
    Column('E-Computer-NoInternet-Households', Float),
    Column('E-Computer-NoInternet-Households-Race_Hispanic_Latino-Whitealone', Float),
    Column('PE-Computer-NoInternet-Households', Float),
    Column('PE-Computer-NoInternet-Households-Race_Hispanic_Latino-Whitealone', Float),
    Column('E-NoComputer-Households', Float),
    Column('E-NoComputer-Households-Race_Hispanic_Latino-Whitealone', Float),
    Column('PE-NoComputer-Households', Float),
    Column('PE-NoComputer-Households-Race_Hispanic_Latino-Whitealone', Float),
    Column('E-Total-Households-Race_Hispanic_Latino-BlackorAfricanAmericanalone', Float),
    Column('E-Computer-Broadband-Households-Race_Hispanic_Latino-BlackorAfricanAmericanalone', Float),
    Column('PE-Computer-Broadband-Households-Race_Hispanic_Latino-BlackorAfricanAmericanalone', Float),
    Column('E-Computer-NoInternet-Households-Race_Hispanic_Latino-BlackorAfricanAmericanalone', Float),
    Column('PE-Computer-NoInternet-Households-Race_Hispanic_Latino-BlackorAfricanAmericanalone', Float),
    Column('E-NoComputer-Households-Race_Hispanic_Latino-BlackorAfricanAmericanalone', Float),
    Column('PE-NoComputer-Households-Race_Hispanic_Latino-BlackorAfricanAmericanalone', Float),
    Column('E-Total-Households-Race_Hispanic_Latino-AmericanIndianandAlaskaNativealone', Float),
    Column('E-Computer-Broadband-Households-Race_Hispanic_Latino-AmericanIndianandAlaskaNativealone', Float),
    Column('PE-Computer-Broadband-Households-Race_Hispanic_Latino-AmericanIndianandAlaskaNativealone', Float),
    Column('E-Computer-NoInternet-Households-Race_Hispanic_Latino-AmericanIndianandAlaskaNativealone', Float),
    Column('PE-Computer-NoInternet-Households-Race_Hispanic_Latino-AmericanIndianandAlaskaNativealone', Float),
    Column('E-NoComputer-Households-Race_Hispanic_Latino-AmericanIndianandAlaskaNativealone', Float),
    Column('PE-NoComputer-Households-Race_Hispanic_Latino-AmericanIndianandAlaskaNativealone', Float),
    Column('E-Total-Households-Race_Hispanic_Latino-Asianalone', Float),
    Column('E-Computer-Broadband-Households-Race_Hispanic_Latino-Asianalone', Float),
    Column('PE-Computer-Broadband-Households-Race_Hispanic_Latino-Asianalone', Float),
    Column('E-Computer-NoInternet-Households-Race_Hispanic_Latino-Asianalone', Float),
    Column('PE-Computer-NoInternet-Households-Race_Hispanic_Latino-Asianalone', Float),
    Column('E-NoComputer-Households-Race_Hispanic_Latino-Asianalone', Float),
    Column('PE-NoComputer-Households-Race_Hispanic_Latino-Asianalone', Float),
    Column('E-Total-Households-Race_Hispanic_Latino-NativeHawaiianandOtherPacificIslanderalone', Float),
    Column('E-Computer-Broadband-Households-Race_Hispanic_Latino-NativeHawaiianandOtherPacificIslanderalone', Float),
    Column('PE-Computer-Broadband-Households-Race_Hispanic_Latino-NativeHawaiianandOtherPacificIslanderalone', Float),
    Column('E-Computer-NoInternet-Households-Race_Hispanic_Latino-NativeHawaiianandOtherPacificIslanderalone', Float),
    Column('PE-Computer-NoInternet-Households-Race_Hispanic_Latino-NativeHawaiianandOtherPacificIslanderalone', Float),
    Column('E-NoComputer-Households-Race_Hispanic_Latino-NativeHawaiianandOtherPacificIslanderalone', Float),
    Column('PE-NoComputer-Households-Race_Hispanic_Latino-NativeHawaiianandOtherPacificIslanderalone', Float),
    Column('E-Total-Households-Race_Hispanic_Latino-Someotherracealone', Float),
    Column('E-Computer-Broadband-Households-Race_Hispanic_Latino-Someotherracealone', Float),
    Column('PE-Computer-Broadband-Households-Race_Hispanic_Latino-Someotherracealone', Float),
    Column('E-Computer-NoInternet-Households-Race_Hispanic_Latino-Someotherracealone', Float),
    Column('PE-Computer-NoInternet-Households-Race_Hispanic_Latino-Someotherracealone', Float),
    Column('E-NoComputer-Households-Race_Hispanic_Latino-Someotherracealone', Float),
    Column('PE-NoComputer-Households-Race_Hispanic_Latino-Someotherracealone', Float),
    Column('E-Total-Households-Race_Hispanic_Latino-Twoormoreraces', Float),
    Column('E-Computer-Broadband-Households-Race_Hispanic_Latino-Twoormoreraces', Float),
    Column('PE-Computer-Broadband-Households-Race_Hispanic_Latino-Twoormoreraces', Float),
    Column('E-Computer-NoInternet-Households-Race_Hispanic_Latino-Twoormoreraces', Float),
    Column('PE-Computer-NoInternet-Households-Race_Hispanic_Latino-Twoormoreraces', Float),
    Column('E-NoComputer-Households-Race_Hispanic_Latino-Twoormoreraces', Float),
    Column('PE-NoComputer-Households-Race_Hispanic_Latino-Twoormoreraces', Float),
    Column('E-Total-Households-Race_Hispanic_Latino-HispanicorLatinoorigin(ofanyrace)', Float),
    Column('E-Computer-Broadband-Households-Race_Hispanic_Latino-HispanicorLatinoorigin(ofanyrace)', Float),
    Column('PE-Computer-Broadband-Households-Race_Hispanic_Latino-HispanicorLatinoorigin(ofanyrace)', Float),
    Column('E-Computer-NoInternet-Households-Race_Hispanic_Latino-HispanicorLatinoorigin(ofanyrace)', Float),
    Column('PE-Computer-NoInternet-Households-Race_Hispanic_Latino-HispanicorLatinoorigin(ofanyrace)', Float),
    Column('E-NoComputer-Households-Race_Hispanic_Latino-HispanicorLatinoorigin(ofanyrace)', Float),
    Column('PE-NoComputer-Households-Race_Hispanic_Latino-HispanicorLatinoorigin(ofanyrace)', Float),
    Column('E-Total-Households-Race_Hispanic_Latino-Whitealone,notHispanicorLatino', Float),
    Column('E-Computer-Broadband-Households-Race_Hispanic_Latino-Whitealone,notHispanicorLatino', Float),
    Column('PE-Computer-Broadband-Households-Race_Hispanic_Latino-Whitealone,notHispanicorLatino', Float),
    Column('E-Computer-NoInternet-Households-Race_Hispanic_Latino-Whitealone,notHispanicorLatino', Float),
    Column('PE-Computer-NoInternet-Households-Race_Hispanic_Latino-Whitealone,notHispanicorLatino', Float),
    Column('E-NoComputer-Households-Race_Hispanic_Latino-Whitealone,notHispanicorLatino', Float),
    Column('PE-NoComputer-Households-Race_Hispanic_Latino-Whitealone,notHispanicorLatino', Float),
    Column('E-Total-Households-EDUATTAINfor25up', Float),
    Column('E-Computer-Broadband-Households-EDUATTAINfor25up', Float),
    Column('PE-Computer-Broadband-Households-EDUATTAINfor25up', Float),
    Column('E-Computer-NoInternet-Households-EDUATTAINfor25up', Float),
    Column('PE-Computer-NoInternet-Households-EDUATTAINfor25up', Float),
    Column('E-NoComputer-Households-EDUATTAINfor25up', Float),
    Column('PE-NoComputer-Households-EDUATTAINfor25up', Float),
    Column('E-Total-Households-EDUATTAINfor25up-Lessthanhighschoolgraduateorequivalency', Float),
    Column('E-Computer-Broadband-Households-EDUATTAINfor25up-Lessthanhighschoolgraduateorequivalency', Float),
    Column('PE-Computer-Broadband-Households-EDUATTAINfor25up-Lessthanhighschoolgraduateorequivalency', Float),
    Column('E-Computer-NoInternet-Households-EDUATTAINfor25up-Lessthanhighschoolgraduateorequivalency', Float),
    Column('PE-Computer-NoInternet-Households-EDUATTAINfor25up-Lessthanhighschoolgraduateorequivalency', Float),
    Column('E-NoComputer-Households-EDUATTAINfor25up-Lessthanhighschoolgraduateorequivalency', Float),
    Column('PE-NoComputer-Households-EDUATTAINfor25up-Lessthanhighschoolgraduateorequivalency', Float),
    Column('E-Total-Households-EDUATTAINfor25up-Highschoolgraduate(includesequivalency)_somecollegeorassociatesdegree', Float),
    Column('E-Computer-Broadband-Households-EDUATTAINfor25up-Highschoolgraduate(includesequivalency)_somecollegeorassociatesdegree', Float),
    Column('PE-Computer-Broadband-Households-EDUATTAINfor25up-Highschoolgraduate(includesequivalency)_somecollegeorassociatesdegree', Float),
    Column('E-Computer-NoInternet-Households-EDUATTAINfor25up-Highschoolgraduate(includesequivalency)_somecollegeorassociatesdegree', Float),
    Column('PE-Computer-NoInternet-Households-EDUATTAINfor25up-Highschoolgraduate(includesequivalency)_somecollegeorassociatesdegree', Float),
    Column('E-NoComputer-Households-EDUATTAINfor25up-Highschoolgraduate(includesequivalency)_somecollegeorassociatesdegree', Float),
    Column('PE-NoComputer-Households-EDUATTAINfor25up-Highschoolgraduate(includesequivalency)_somecollegeorassociatesdegree', Float),
    Column('E-Total-Households-EDUATTAINfor25up-Bachelorsdegreeorhigher', Float),
    Column('E-Computer-Broadband-Households-EDUATTAINfor25up-Bachelorsdegreeorhigher', Float),
    Column('PE-Computer-Broadband-Households-EDUATTAINfor25up-Bachelorsdegreeorhigher', Float),
    Column('E-Computer-NoInternet-Households-EDUATTAINfor25up-Bachelorsdegreeorhigher', Float),
    Column('PE-Computer-NoInternet-Households-EDUATTAINfor25up-Bachelorsdegreeorhigher', Float),
    Column('E-NoComputer-Households-EDUATTAINfor25up-Bachelorsdegreeorhigher', Float),
    Column('PE-NoComputer-Households-EDUATTAINfor25up-Bachelorsdegreeorhigher', Float), extend_existing=True,
)

# %%
meta.create_all(engine)
# Out:
# 2020-07-24 16:58:16,324 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-07-24 16:58:16,327 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-24 16:58:16,330 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-07-24 16:58:16,331 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-24 16:58:16,335 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("s2802")
# 2020-07-24 16:58:16,338 INFO sqlalchemy.engine.base.Engine ()

# %%
conn = engine.connect()
# Out:
# 2020-07-24 19:23:16,006 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-07-24 19:23:16,010 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-24 19:23:16,014 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-07-24 19:23:16,017 INFO sqlalchemy.engine.base.Engine ()

# %%
engine.table_names()
# Out:
# 2020-07-24 19:23:51,108 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2020-07-24 19:23:51,112 INFO sqlalchemy.engine.base.Engine ()
# ['Census_Data', 'Internet_Data', 'Meta_Data']

# %%
meta
# Out:
# MetaData(bind=None)

# %% [markdown]
# # Now make the table

# %%
df = pd.read_csv("S2802.csv")

df = df.astype({"fips_id": "object"})
df.dtypes
# Out:
# id                                                                            object
# fips_id                                                                       object
# GeographicAreaName                                                            object
# tract_name                                                                    object
# county_name                                                                   object
#                                                                                ...
# PE-Computer-Broadband-Households-EDUATTAINfor25up-Bachelorsdegreeorhigher     object
# E-Computer-NoInternet-Households-EDUATTAINfor25up-Bachelorsdegreeorhigher      int64
# PE-Computer-NoInternet-Households-EDUATTAINfor25up-Bachelorsdegreeorhigher    object
# E-NoComputer-Households--EDUATTAINfor25up-Bachelorsdegreeorhigher              int64
# PE-NoComputer-Households--EDUATTAINfor25up-Bachelorsdegreeorhigher            object
# Length: 104, dtype: object

# %%
df
# Out:
#                        id      fips_id  \
# 0    1400000US41001950100  41001950100
# 1    1400000US41001950200  41001950200
# 2    1400000US41001950300  41001950300
# 3    1400000US41001950400  41001950400
# 4    1400000US41001950500  41001950500
# ..                    ...          ...
# 829  1400000US41071030702  41071030702
# 830  1400000US41071030801  41071030801
# 831  1400000US41071030802  41071030802
# 832  1400000US41071030900  41071030900
# 833  1400000US41071031000  41071031000
#
#                               GeographicAreaName           tract_name  \
# 0        Census Tract 9501, Baker County, Oregon    Census Tract 9501
# 1        Census Tract 9502, Baker County, Oregon    Census Tract 9502
# 2        Census Tract 9503, Baker County, Oregon    Census Tract 9503
# 3        Census Tract 9504, Baker County, Oregon    Census Tract 9504
# 4        Census Tract 9505, Baker County, Oregon    Census Tract 9505
# ...

# %%
fcc = pd.read_csv("fcc_data.csv")
fcc
# Out:
#      Unnamed: 0  logrecno  provider_id       frn       providername  \
# 0             0      4268        48582  17678236  Webformix Company
# 1             1      4269        48582  17678236  Webformix Company
# 2             2      4270        48582  17678236  Webformix Company
# 3             3      4271        48582  17678236  Webformix Company
# 4             4      4272        48582  17678236  Webformix Company
# ..          ...       ...          ...       ...                ...
# 995         995      5263        48582  17678236  Webformix Company
# 996         996      5264        48582  17678236  Webformix Company
# 997         997      5265        48582  17678236  Webformix Company
# 998         998      5266        48582  17678236  Webformix Company
# 999         999      5267        48582  17678236  Webformix Company
#
#        dbaname holdingcompanyname  hoconum          hocofinal stateabbr  \
# 0    Webformix  Webformix Company   290118  Webformix Company        OR
# ...

# %%
fcc_df = fcc[['provider_id', 'dbaname', 'stateabbr', 'blockcode', 'techcode', 'consumer', 'maxaddown', 
              'maxadup', 'maxcirdown', 'maxcirup']]

# %%
#figure out data type
#change data type to string
#then:
fcc_df2 = fcc_df
fcc_df2["tract"] = [str(tract)[0:11] for tract in fcc_df2["blockcode"]]
fcc_df2
# Out:
# /Users/lauranicholson/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#      provider_id    dbaname stateabbr        blockcode  techcode  consumer  \
# 0          48582  Webformix        OR  410139501002019        70         1
# 1          48582  Webformix        OR  410139503002023        70         1
# 2          48582  Webformix        OR  410139502002027        70         1
# 3          48582  Webformix        OR  410139501003004        70         1
# 4          48582  Webformix        OR  410139504001109        70         1
# ..           ...        ...       ...              ...       ...       ...
# ...

# %%
merged_df = pd.merge(df, fcc_df2, how= "left", left_on="fips_id", right_on="tract")
#merged_df

merge2 = pd.merge(df, fcc_df2, how= "inner", left_on="fips_id", right_on="tract")
merge2
# Out:
# Empty DataFrame
# ...

# %%
df.to_sql('s2802', con=conn, if_exists='replace',
           index_label=None)
# Out:
# 2020-07-24 16:58:30,006 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("s2802")
# 2020-07-24 16:58:30,008 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-24 16:58:30,011 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("s2802")
# 2020-07-24 16:58:30,013 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-24 16:58:30,017 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2020-07-24 16:58:30,021 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-24 16:58:30,023 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("s2802")
# 2020-07-24 16:58:30,024 INFO sqlalchemy.engine.base.Engine ()
# 2020-07-24 16:58:30,041 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 's2802' AND type = 'table'
# 2020-07-24 16:58:30,043 INFO sqlalchemy.engine.base.Engine ()
# ...

# %%
from sqlalchemy.sql import select
#s = select([Census_Data])
#result = conn.execute(s)
conn.execute("SELECT * FROM Census_Data")
#[(0, 'User 4'), (1, 'User 5')]
# Out:
# 2020-07-24 19:24:57,641 INFO sqlalchemy.engine.base.Engine SELECT * FROM Census_Data
# 2020-07-24 19:24:57,643 INFO sqlalchemy.engine.base.Engine ()

# %%
import time
res = conn.execute("SELECT * FROM Census_Data")
for row in res:
    print(row)
    time.sleep(2)
# Out:
# 2020-07-24 19:25:15,362 INFO sqlalchemy.engine.base.Engine SELECT * FROM Census_Data
# 2020-07-24 19:25:15,363 INFO sqlalchemy.engine.base.Engine ()
# (' County, O', 'egon",1255,1255,861,68.6,179,14.3,744,59.3,122,9.7,19,1.5,13,1,98,7.8,44,3.5,394,31.4,325,25.9,185,14.7,260,20.7,525,41.8,2.24,(X),2.64,(X),2806,2806 ... (858 characters truncated) ... 6,1.6,20.7,2,0.1,13,0.5,215,7.6,88,3.1,0,0,56,2,43,1.5,10,0.4,19,0.7,56,2,116,4.1,8,0.3,0,0,50,1.8,38,1.3,0,0,33,1.2,0,0,1255,1255,1118,89.1,881,70.2')
# (' County, O', 'egon",1422,1422,884,62.2,379,26.7,679,47.7,294,20.7,59,4.1,14,1,146,10.3,71,5,538,37.8,449,31.6,161,11.3,445,31.3,505,35.5,2.42,(X),3,(X),3435,3435,1 ... (829 characters truncated) ... ,0,0,17.3,13,0.4,0,0,238,6.9,144,4.2,0,0,158,4.6,51,1.5,12,0.3,21,0.6,59,1.7,207,6,0,0,0,0,49,1.4,0,0,15,0.4,15,0.4,0,0,1422,1422,1202,84.5,1050,73.8')
# ...

# %%
result2 = result.fetchall()

query = db.select([census, state_fact])
df2 = pd.DataFrame(s2802)
df2

# %%
results = conn.execute(select([S2802])).fetchall()
df2 = pd.DataFrame(results)
df2.columns = results[0].keys()
df2.head(4)
# Out:
# 2020-07-24 17:30:40,385 INFO sqlalchemy.engine.base.Engine SELECT s2802.id, s2802.fips_id, s2802."GeographicAreaName", s2802.tract_name, s2802.county_name, s2802.state, s2802."E-Households", s2802."E-Total-Households-Race_Hispanic_Latino-Whitealone", s2802."E-Computer-Broadband-Totalhouseholds", s2802."E-Computer-Broadband-Households-Race_Hispanic_Latino-Whitealone", s2802."PE-Computer-Broadband-Household", s2802."PE-Computer-Broadband-Households-Race_Hispanic_Latino-Whitealone", s2802."E-Computer-NoInternet-Households", s2802."E-Computer-NoInternet-Households-Race_Hispanic_Latino-Whitealone", s2802."PE-Computer-NoInternet-Households", s2802."PE-Computer-NoInternet-Households-Race_Hispanic_Latino-Whitealone", s2802."E-NoComputer-Households", s2802."E-NoComputer-Households-Race_Hispanic_Latino-Whitealone", s2802."PE-NoComputer-Households", s2802."PE-NoComputer-Households-Race_Hispanic_Latino-Whitealone", s2802."E-Total-Households-Race_Hispanic_Latino-BlackorAfricanAmericanalone", s280
# ...

# %% [markdown]
# from sqlalchemy.sql import text
# >>> s = text(
# ...     "SELECT users.fullname || ', ' || addresses.email_address AS title "
# ...         "FROM users, addresses "
# ...         "WHERE users.id = addresses.user_id "
# ...         "AND users.name BETWEEN :x AND :y "
# ...         "AND (addresses.email_address LIKE :e1 "
# ...             "OR addresses.email_address LIKE :e2)")
# >>> conn.execute(s, x='m', y='z', e1='%@aol.com', e2='%@msn.com').fetchall()
# SELECT users.fullname || ', ' || addresses.email_address AS title
# FROM users, addresses
# WHERE users.id = addresses.user_id AND users.name BETWEEN ? AND ? AND
# (addresses.email_address LIKE ? OR addresses.email_address LIKE ?)
# ('m', 'z', '%@aol.com', '%@msn.com')

# %%
SQL :
SELECT * FROM census
WHERE state = 'California' AND NOT sex = 'M'
SQLAlchemy :
db.select([census]).where(db.and_(census.columns.state == 'California', census.columns.sex != 'M'))
