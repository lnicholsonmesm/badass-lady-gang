# %%
import requests
import pandas as pd
import json

# %%
url = "https://opendata.fcc.gov/resource/sgz3-kiqt.json?stateabbr=OR"
request = requests.get(url).json()

# %%
request
# Out:
# [{'logrecno': '4268',
#   'provider_id': '48582',
#   'frn': '0017678236',
#   'providername': 'Webformix Company',
#   'dbaname': 'Webformix',
#   'holdingcompanyname': 'Webformix Company',
#   'hoconum': '290118',
#   'hocofinal': 'Webformix Company',
#   'stateabbr': 'OR',
#   'blockcode': '410139501002019',
#   'techcode': '70',
#   'consumer': '1',
#   'maxaddown': '40',
#   'maxadup': '10',
#   'business': '1',
#   'maxcirdown': '40',
#   'maxcirup': '10'},
#  {'logrecno': '4269',
#   'provider_id': '48582',
#   'frn': '0017678236',
#   'providername': 'Webformix Company',
#   'dbaname': 'Webformix',
#   'holdingcompanyname': 'Webformix Company',
#   'hoconum': '290118',
#   'hocofinal': 'Webformix Company',
#   'stateabbr': 'OR',
#   'blockcode': '410139503002023',
#   'techcode': '70',
#   'consumer': '1',
#   'maxaddown': '40',
#   'maxadup': '10',
#   'business': '1',
#   'maxcirdown': '40',
#   'maxcirup': '10'},
#  {'logrecno': '4270',
#   'provider_id': '48582',
# ...

# %%
df = pd.DataFrame.from_dict(request)
df
# Out:
#     logrecno provider_id         frn       providername    dbaname  \
# 0       4268       48582  0017678236  Webformix Company  Webformix
# 1       4269       48582  0017678236  Webformix Company  Webformix
# 2       4270       48582  0017678236  Webformix Company  Webformix
# 3       4271       48582  0017678236  Webformix Company  Webformix
# 4       4272       48582  0017678236  Webformix Company  Webformix
# ..       ...         ...         ...                ...        ...
# 995     5263       48582  0017678236  Webformix Company  Webformix
# 996     5264       48582  0017678236  Webformix Company  Webformix
# 997     5265       48582  0017678236  Webformix Company  Webformix
# 998     5266       48582  0017678236  Webformix Company  Webformix
# 999     5267       48582  0017678236  Webformix Company  Webformix
#
#     holdingcompanyname hoconum          hocofinal stateabbr        blockcode  \
# 0    Webformix Company  290118  Webformix Company        OR  410139501002019
# ...

# %%
df.to_csv("fcc_data.csv")

# %% [markdown]
# blockcode
# providername
# hocofinal

# %%
'''
'logrecno' 'provider_id'
 'frn' 'providername' 'dbaname' 'holdingcompanyname'
 'hoconum'
 'hocofinal'
 'stateabbr'
 'blockcode' ** Keep--
 'techcode'
 'consumer' 'maxaddown'
 'maxadup' 'business' 'maxcirdown' 'maxcirup'
 
 '''
# Out:
# {'logrecno': '4268', 'provider_id': '48582', 'frn': '0017678236', 'providername': 'Webformix Company', 'dbaname': 'Webformix', 'holdingcompanyname': 'Webformix Company', 'hoconum': '290118', 'hocofinal': 'Webformix Company', 'stateabbr': 'OR', 'blockcode': '410139501002019', 'techcode': '70', 'consumer': '1', 'maxaddown': '40', 'maxadup': '10', 'business': '1', 'maxcirdown': '40', 'maxcirup': '10'}
# {'logrecno': '4269', 'provider_id': '48582', 'frn': '0017678236', 'providername': 'Webformix Company', 'dbaname': 'Webformix', 'holdingcompanyname': 'Webformix Company', 'hoconum': '290118', 'hocofinal': 'Webformix Company', 'stateabbr': 'OR', 'blockcode': '410139503002023', 'techcode': '70', 'consumer': '1', 'maxaddown': '40', 'maxadup': '10', 'business': '1', 'maxcirdown': '40', 'maxcirup': '10'}
# ...
